# %% [markdown]
# ## Data Wrangling of Singapore Map Data
# ### This file contains osm file to mongodb collection and some evidence of data wrangling. It is more of a scratch space. You can find the singapore website parser and cleaner script in the script.py file.

# %%
# initialize
import xml.etree.cElementTree as ET
from pprint import pprint
import re
import operator
import codecs
import json
import requests
from bs4 import BeautifulSoup as bs
from pymongo import MongoClient
from collections import defaultdict, OrderedDict

filename='datasets/singapore.osm'

client = MongoClient("mongodb://localhost:27017")
db = client.openmap

# %% [markdown]
# ### Keys
# > I quickly look at tags and its keys attribute to see what we are dealing with

# %%
# count tags function
def count_tags(filename):
    tags = {}
    for event, elem in ET.iterparse(filename):
        if event == 'end':
            if elem.tag not in tags.keys():
                tags[elem.tag] = 0
            tags[elem.tag] += 1
    return tags

# %%
# tags and count of its occurrence
count_tags(filename)
# Out:
# {'bounds': 1,
#  'member': 71669,
#  'nd': 1215326,
#  'node': 987336,
#  'osm': 1,
#  'relation': 2003,
#  'tag': 494276,
#  'way': 147092}

# %%
# Identify problematic characters only
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# record keys to look at
def key_type(element, formats, keys):
    if element.tag == "tag":
        for elem in element.iter('tag'):
            if problemchars.match(elem.attrib['k']):
                formats['problem'] += 1
            else:
                formats['noproblem'] += 1
                
            if elem.attrib['k'] not in keys.keys():
                keys[elem.attrib['k']] = 0
            keys[elem.attrib['k']] += 1
    
    return {'formats': formats, 'keys': keys}

def process_map(filename):
    formats = {"problem": 0, "noproblem": 0}
    keys = {}
    for _, element in ET.iterparse(filename):
        out = key_type(element, formats, keys)

    return out

# %%
keys_descr = process_map(filename)

# %%
keys_descr['formats']
# Out:
# {'noproblem': 494276, 'problem': 0}

# %%
# Keys and the count of its occurrence
sorted(keys_descr['keys'].items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('highway', 73693),
#  ('building', 65708),
#  ('name', 57168),
#  ('source', 37221),
#  ('addr:street', 28671),
#  ('addr:city', 22988),
#  ('addr:housenumber', 19412),
#  ('addr:postcode', 19069),
#  ('oneway', 14573),
#  ('addr:country', 10371),
#  ('garmin_type', 10122),
#  ('amenity', 8485),
#  ('catmp-RoadID', 7877),
#  ('created_by', 7401),
#  ('service', 5180),
#  ('location', 4934),
#  ('asset_ref', 4921),
#  ('route_ref', 4866),
#  ('ref', 3454),
#  ('landuse', 3308),
#  ('access', 3081),
#  ('leisure', 3062),
#  ('natural', 2867),
#  ('surface', 2806),
#  ('layer', 2700),
#  ('foot', 2684),
#  ('bridge', 2538),
#  ('building:levels', 2195),
#  ('bicycle', 2093),
#  ('type', 2044),
#  ('power', 2009),
#  ('lanes', 1498),
#  ('maxspeed', 1415),
#  ('sport', 1359),
#  ('shop', 1345),
#  ('waterway', 1229),
#  ('barrier', 1113),
#  ('place', 1110),
#  ('man_made', 964),
#  ('seamark:type', 954),
#  ('parking', 935),
#  ('railway', 904),
#  ('website', 851),
#  ('motorcar', 839),
#  ('note', 833),
#  ('name:zh', 818),
#  ('religion', 793),
#  ('hgv', 768),
#  ('goods', 759),
#  ('lit', 713),
#  ('emergency', 709),
#  ('psv', 699),
#  ('phone', 698),
#  ('operator', 687),
#  ('tourism', 685),
#  ('taxi', 678),
#  ('garmin_road_class', 675),
#  ('building:part', 672),
#  ('building:use', 670),
#  ('horse', 665),
#  ('network', 657),
#  ('addr:housename', 642),
#  ('cuisine', 642),
#  ('golf', 641),
#  ('route', 639),
#  ('name:en', 623),
#  ('tunnel', 606),
#  ('aeroway', 574),
#  ('motor_vehicle', 563),
#  ('height', 560),
#  ('residential', 525),
#  ('covered', 511),
#  ('alt_name', 483),
#  ('name:ms', 454),
#  ('sidewalk', 441),
#  ('wheelchair', 439),
#  ('public_transport', 366),
#  ('seamark:name', 362),
#  ('is_in:country', 352),
#  ('school', 343),
#  ('fixme', 325),
#  ('water', 321),
#  ('is_in:state', 316),
#  ('seamark:light:character', 316),
#  ('area', 316),
#  ('seamark:light:colour', 316),
#  ('crossing', 307),
#  ('exit_to', 301),
#  ('seamark:light:period', 291),
#  ('width', 278),
#  ('gauge', 248),
#  ('roof:shape', 240),
#  ('cycleway', 239),
#  ('wikipedia', 236),
#  ('old_name', 221),
#  ('opening_hours', 208),
#  ('email', 204),
#  ('colour', 195),
#  ('gns:dsg', 193),
#  ('is_in:country_code', 191),
#  ('is_in', 190),
#  ('junction', 189),
#  ('construction', 186),
#  ('restriction', 184),
#  ('footway', 179),
#  ('tee', 177),
#  ('building:level', 165),
#  ('cables', 161),
#  ('motorroad', 159),
#  ('bus', 157),
#  ('building:min_level', 156),
#  ('motorcycle', 156),
#  ('frequency', 149),
#  ('voltage', 149),
#  ('destination', 146),
#  ('office', 145),
#  ('public_transport:version', 145),
#  ('toll', 141),
#  ('seamark:light:range', 138),
#  ('tracktype', 136),
#  ('alt_name:ms', 134),
#  ('seamark:light:height', 133),
#  ('station', 129),
#  ('shelter', 129),
#  ('designation', 125),
#  ('crossing_ref', 125),
#  ('is_in:county', 123),
#  ('fee', 121),
#  ('is_in:region', 118),
#  ('sac_scale', 113),
#  ('seamark:buoy_lateral:category', 113),
#  ('seamark:buoy_lateral:shape', 113),
#  ('seamark:buoy_lateral:colour', 113),
#  ('seamark:light:reference', 111),
#  ('internet_access', 109),
#  ('segregated', 108),
#  ('incline', 107),
#  ('trail_visibility', 106),
#  ('seamark:buoy_lateral:system', 105),
#  ('from', 100),
#  ('to', 100),
#  ('content', 100),
#  ('seamark:topmark:shape', 99),
#  ('seamark:topmark:colour', 96),
#  ('int_ref', 94),
#  ('capacity', 94),
#  ('min_height', 94),
#  ('fax', 88),
#  ('seamark:buoy_special_purpose:shape', 85),
#  ('seamark:buoy_special_purpose:colour', 84),
#  ('seamark:light:group', 83),
#  ('salt', 83),
#  ('bench', 82),
#  ('brand', 82),
#  ('description', 81),
#  ('postal_code', 80),
#  ('tidal', 79),
#  ('vehicle', 78),
#  ('stars', 77),
#  ('internet_access:fee', 72),
#  ('design', 71),
#  ('shelter_type', 66),
#  ('roof:height', 66),
#  ('denomination', 65),
#  ('Comment', 64),
#  ('GPS_Time', 64),
#  ('GPS_Second', 64),
#  ('rooms', 64),
#  ('GPS_Date', 64),
#  ('Filt_Pos', 63),
#  ('Max_PDOP', 63),
#  ('traffic_calming', 63),
#  ('Max_HDOP', 63),
#  ('Feat_Name', 63),
#  ('Datafile', 63),
#  ('Rcvr_Type', 63),
#  ('Corr_Type', 63),
#  ('Unfilt_Pos', 63),
#  ('Data_Dicti', 63),
#  ('GPS_Week', 63),
#  ('Std_Dev', 62),
#  ('Vert_Prec', 62),
#  ('Horz_Prec', 62),
#  ('GNSS_Heigh', 62),
#  ('submarine', 61),
#  ('atm', 59),
#  ('boat', 59),
#  ('smoking', 58),
#  ('ski', 57),
#  ('historic', 56),
#  ('entrance', 54),
#  ('Update_Sta', 52),
#  ('snowmobile', 51),
#  ('Longitude', 51),
#  ('electrified', 51),
#  ('boundary', 51),
#  ('Point_ID', 51),
#  ('Latitude', 51),
#  ('proposed', 51),
#  ('traffic_signals', 51),
#  ('underground', 48),
#  ('roof:colour', 45),
#  ('mtb:scale:imba', 44),
#  ('tactile_paving', 43),
#  ('information', 42),
#  ('addr:unit', 42),
#  ('substation', 42),
#  ('seamark:beacon_lateral:category', 41),
#  ('seamark:beacon_lateral:colour', 41),
#  ('seamark:beacon_lateral:system', 40),
#  ('payment:bitcoin', 40),
#  ('diet:vegetarian', 37),
#  ('name:hi', 37),
#  ('wetland', 37),
#  ('destination:en', 37),
#  ('handrail', 36),
#  ('name:my', 35),
#  ('seamark:beacon_special_purpose:colour', 35),
#  ('admin_level', 34),
#  ('ele', 33),
#  ('supervised', 33),
#  ('tower:type', 32),
#  ('level', 30),
#  ('park_ride', 30),
#  ('step_count', 30),
#  ('leaf_type', 29),
#  ('seamark:information', 29),
#  ('seamark:cable_submarine:category', 29),
#  ('seamark:buoy_special_purpose:category', 28),
#  ('mtb:scale', 28),
#  ('diet:vegan', 27),
#  ('backrest', 27),
#  ('seamark:pipeline_submarine:product', 27),
#  ('int_name', 27),
#  ('seats', 27),
#  ('name:ja', 27),
#  ('route_master', 27),
#  ('maxspeed:type', 26),
#  ('subsea', 26),
#  ('border_type', 26),
#  ('cutting', 26),
#  ('seamark:pipeline_submarine:category', 26),
#  ('seamark:gate:category', 25),
#  ('bicycle_parking', 25),
#  ('OBJECTID', 25),
#  ('is_in:city', 25),
#  ('building:colour', 25),
#  ('leaf_cycle', 24),
#  ('takeaway', 24),
#  ('material', 24),
#  ('wikidata', 23),
#  ('state', 23),
#  ('name:de', 23),
#  ('building:height', 22),
#  ('turn:lanes', 22),
#  ('maritime', 22),
#  ('source:maxspeed', 22),
#  ('communication', 22),
#  ('contact:phone', 22),
#  ('seamark:buoy_cardinal:colour_pattern', 21),
#  ('seamark:buoy_cardinal:colour', 21),
#  ('genus', 21),
#  ('addr:place', 21),
#  ('name:ru', 21),
#  ('maxheight', 21),
#  ('fuel:octane_95', 21),
#  ('seamark:obstruction:category', 21),
#  ('trees', 21),
#  ('seamark:buoy_cardinal:category', 21),
#  ('disused', 20),
#  ('via', 20),
#  ('seamark:buoy_cardinal:shape', 20),
#  ('fuel:diesel', 20),
#  ('roof:type:height', 20),
#  ('usage', 20),
#  ('button_operated', 20),
#  ('name:pl', 19),
#  ('roof:material', 19),
#  ('communication:radio', 19),
#  ('lanes:forward', 19),
#  ('distance', 18),
#  ('country', 18),
#  ('FIXME', 18),
#  ('seamark:beacon_cardinal:category', 17),
#  ('name:fr', 17),
#  ('seamark:beacon_cardinal:colour', 17),
#  ('lanes:backward', 17),
#  ('seamark:beacon_cardinal:colour_pattern', 17),
#  ('hiking', 16),
#  ('fuel:octane_98', 16),
#  ('seamark:beacon_lateral:shape', 15),
#  ('map_size', 15),
#  ('zone:traffic', 14),
#  ('seamark:light:1:height', 14),
#  ('seamark:light:1:range', 14),
#  ('name:he', 14),
#  ('seamark:beacon_special_purpose:category', 14),
#  ('zone:maxspeed', 14),
#  ('seamark:light:1:character', 14),
#  ('seamark:light:1:colour', 14),
#  ('short_name', 14),
#  ('seamark:radar_reflector', 14),
#  ('seamark:radar_transponder:category', 13),
#  ('name:botanical', 13),
#  ('name:cs', 13),
#  ('min_level', 13),
#  ('seamark:light:1:sector_end', 13),
#  ('seamark:light:1:sector_start', 13),
#  ('seamark:light:1:period', 12),
#  ('map_type', 12),
#  ('line', 12),
#  ('aerialway', 12),
#  ('highways_agency:area', 12),
#  ('roof:orientation', 12),
#  ('seamark:radar_transponder:group', 12),
#  ('name:uk', 11),
#  ('name:it', 11),
#  ('Northing', 11),
#  ('name:pt', 11),
#  ('name:sv', 11),
#  ('name:es', 11),
#  ('tourist_bus', 11),
#  ('ref:De_Lijn', 11),
#  ('Easting', 11),
#  ('contact:website', 11),
#  ('name:nl', 11),
#  ('seamark:beacon_special_purpose:shape', 10),
#  ('military', 10),
#  ('name:tr', 10),
#  ('name:ta', 10),
#  ('name:ar', 10),
#  ('TMC:cid_58:tabcd_1:LocationCode', 10),
#  ('name:hu', 10),
#  ('halal', 10),
#  ('3dr:type', 10),
#  ('fence_type', 10),
#  ('TMC:cid_58:tabcd_1:LCLversion', 10),
#  ('passenger_lines', 10),
#  ('TMC:cid_58:tabcd_1:Class', 10),
#  ('name:id', 9),
#  ('name:fi', 9),
#  ('name:sl', 9),
#  ('name:sk', 9),
#  ('seamark:wall:category', 9),
#  ('name:hr', 9),
#  ('url', 9),
#  ('building:levels:underground', 9),
#  ('name:lt', 9),
#  ('path', 9),
#  ('toilets:wheelchair', 9),
#  ('seamark:light:category', 8),
#  ('seamark:buoy_isolated_danger:colour', 8),
#  ('seamark:buoy_isolated_danger:colour_pattern', 8),
#  ('seamark:landmark:height', 8),
#  ('duration', 8),
#  ('pedestrian', 8),
#  ('iata', 8),
#  ('name:et', 8),
#  ('developer', 8),
#  ('gay', 8),
#  ('seamark:light:exhibition', 8),
#  ('seamark:small_craft_facility:category', 8),
#  ('name:da', 8),
#  ('cycleway:left', 8),
#  ('drive_through', 8),
#  ('TMC:cid_58:tabcd_1:Direction', 7),
#  ('icao', 7),
#  ('name:be', 7),
#  ('name:bg', 7),
#  ('seamark:buoy_safe_water:colour', 7),
#  ('TMC:cid_58:tabcd_1:NextLocationCode', 7),
#  ('nat_ref', 7),
#  ('name:fa', 7),
#  ('seamark:buoy_safe_water:colour_pattern', 7),
#  ('seamark:light:sequence', 7),
#  ('embankment', 7),
#  ('name:sr', 7),
#  ('length', 7),
#  ('name:ro', 7),
#  ('name:is', 7),
#  ('seamark:mooring:category', 7),
#  ('ford', 7),
#  ('name:ka', 7),
#  ('name:ko', 7),
#  ('is_in:town', 7),
#  ('name:lv', 7),
#  ('name:lb', 7),
#  ('name:la', 7),
#  ('name:el', 7),
#  ('name:eo', 7),
#  ('ramp', 7),
#  ('direction', 7),
#  ('name:vi', 7),
#  ('levels', 7),
#  ('name:cv', 7),
#  ('seamark:buoy_isolated_danger:shape', 7),
#  ('name:ca', 7),
#  ('vending', 7),
#  ('TMC:cid_58:tabcd_1:PrevLocationCode', 7),
#  ('name:en1', 7),
#  ('smoothness', 7),
#  ('name:nn', 7),
#  ('name:no', 7),
#  ('wifi', 7),
#  ('name:bat-smg', 6),
#  ('name:ur', 6),
#  ('name:map-bms', 6),
#  ('seamark:light:2:character', 6),
#  ('name:br', 6),
#  ('name:bs', 6),
#  ('name:bn', 6),
#  ('name:bo', 6),
#  ('name:bjn', 6),
#  ('name:ba', 6),
#  ('name:bcl', 6),
#  ('name:pa', 6),
#  ('name:sco', 6),
#  ('name:scn', 6),
#  ('name:bxr', 6),
#  ('name:pnb', 6),
#  ('name:be-tarask', 6),
#  ('name:mt', 6),
#  ('name:bug', 6),
#  ('name:mr', 6),
#  ('name:ml', 6),
#  ('name:mn', 6),
#  ('name:mi', 6),
#  ('name:mk', 6),
#  ('name:hif', 6),
#  ('name:fo', 6),
#  ('name:fy', 6),
#  ('capacity:disabled', 6),
#  ('name:tt', 6),
#  ('name:th', 6),
#  ('name:tl', 6),
#  ('name:tg', 6),
#  ('name:te', 6),
#  ('name:pms', 6),
#  ('old_ref', 6),
#  ('seamark:landmark:category', 6),
#  ('name:az', 6),
#  ('name:gan', 6),
#  ('wpt_symbol', 6),
#  ('name:an', 6),
#  ('name:af', 6),
#  ('name:so', 6),
#  ('name:war', 6),
#  ('name:sg', 6),
#  ('name:se', 6),
#  ('name:sa', 6),
#  ('name:arz', 6),
#  ('name:sw', 6),
#  ('name:su', 6),
#  ('name:ss', 6),
#  ('name:sq', 6),
#  ('name:ie', 6),
#  ('seamark:buoy_safe_water:shape', 6),
#  ('name:bpy', 6),
#  ('name:hy', 6),
#  ('name:ht', 6),
#  ('seamark:shoreline_construction:category', 6),
#  ('name:haw', 6),
#  ('name:hak', 6),
#  ('name:xal', 6),
#  ('name:wo', 6),
#  ('name:ceb', 6),
#  ('name:kn', 6),
#  ('name:km', 6),
#  ('name:kk', 6),
#  ('name:ki', 6),
#  ('name:kw', 6),
#  ('name:kv', 6),
#  ('name:ku', 6),
#  ('name:frp', 6),
#  ('fuel', 6),
#  ('name:li', 6),
#  ('name:lij', 6),
#  ('name:ckb', 6),
#  ('name:rw', 6),
#  ('seamark:light:2:height', 6),
#  ('seamark:beacon_lateral:height', 6),
#  ('carriageway_ref', 6),
#  ('name:sah', 6),
#  ('name:udm', 6),
#  ('parking:lane:left', 6),
#  ('name:oc', 6),
#  ('name:os', 6),
#  ('name:or', 6),
#  ('seamark:light:2:range', 6),
#  ('name:yi', 6),
#  ('name:yo', 6),
#  ('name:vo', 6),
#  ('name:ext', 6),
#  ('surveillance', 6),
#  ('fire_hydrant:position', 6),
#  ('name:wuu', 6),
#  ('name:cy', 6),
#  ('name:en2', 6),
#  ('name:simple', 6),
#  ('name:dv', 6),
#  ('name:zh-yue', 6),
#  ('seamark:light:2:colour', 6),
#  ('name:jv', 6),
#  ('name:ug', 6),
#  ('name:jbo', 6),
#  ('name_1', 6),
#  ('name:zh-min-nan', 6),
#  ('name:mhr', 6),
#  ('name:nov', 6),
#  ('name:csb', 6),
#  ('name:pam', 6),
#  ('mtb', 6),
#  ('name:am', 6),
#  ('seamark:rock:water_level', 6),
#  ('fire_hydrant:type', 6),
#  ('name:na', 6),
#  ('name:ne', 6),
#  ('name:nv', 6),
#  ('name:ga', 6),
#  ('name:gd', 6),
#  ('name:gl', 6),
#  ('name:gv', 6),
#  ('name:gu', 6),
#  ('name:ast', 5),
#  ('name:uz', 5),
#  ('name:als', 5),
#  ('name:nds', 5),
#  ('name:ilo', 5),
#  ('name:ia', 5),
#  ('name:lez', 5),
#  ('name:io', 5),
#  ('name:szl', 5),
#  ('hoops', 5),
#  ('name:crh', 5),
#  ('name:ps', 5),
#  ('name:pih', 5),
#  ('name:cdo', 5),
#  ('name:rue', 5),
#  ('name:vec', 5),
#  ('name:ace', 5),
#  ('seamark:light:3:height', 5),
#  ('name:mg', 5),
#  ('name:bi', 5),
#  ('name:tk', 5),
#  ('seamark:beacon_isolated_danger:colour_pattern', 5),
#  ('name:gag', 5),
#  ('name:sm', 5),
#  ('name:sh', 5),
#  ('seamark:light:3:range', 5),
#  ('name:diq', 5),
#  ('seamark:wreck:category', 5),
#  ('name:lmo', 5),
#  ('name:roa-tara', 5),
#  ('name:min', 5),
#  ('name:kl', 5),
#  ('name:ky', 5),
#  ('seamark:light:3:character', 5),
#  ('wood', 5),
#  ('wheelchair:description', 5),
#  ('name:eu', 5),
#  ('seamark:beacon_cardinal:shape', 5),
#  ('parking:condition:left', 5),
#  ('contact:email', 5),
#  ('seamark:light:2:sector_start', 5),
#  ('name:bar', 5),
#  ('seamark:light:3:colour', 5),
#  ('seamark:beacon_isolated_danger:colour', 5),
#  ('name:ce', 5),
#  ('gns:uni', 5),
#  ('name:dsb', 5),
#  ('name:nah', 5),
#  ('estuary', 5),
#  ('tree:height', 5),
#  ('name:mzn', 5),
#  ('underpass', 5),
#  ('reservoir_type', 5),
#  ('delivery', 5),
#  ('name:zh-classical', 5),
#  ('name:qu', 5),
#  ('bus:lanes', 5),
#  ('e-road:class', 5),
#  ('name:fiu-vro', 5),
#  ('seamark:light:2:sector_end', 5),
#  ('maxstay', 5),
#  ('newforest_pathtype', 4),
#  ('social_facility', 4),
#  ('is_in:continent', 4),
#  ('turn:lanes:forward', 4),
#  ('name:etymology:wikidata', 4),
#  ('microbrewery', 4),
#  ('priority_road', 4),
#  ('name:vep', 4),
#  ('name:ff', 4),
#  ('detour', 4),
#  ('seamark:light:3:sector_end', 4),
#  ('maxweight', 4),
#  ('name:ha', 4),
#  ('mtb:type', 4),
#  ('addr:suburb', 4),
#  ('name:ln', 4),
#  ('seamark:light:1:sequence', 4),
#  ('key', 4),
#  ('name:roa-rup', 4),
#  ('cycleway:right', 4),
#  ('loading_gauge', 4),
#  ('aerodrome:type', 4),
#  ('seamark:light:3:sector_start', 4),
#  ('seamark:bridge:clearance_height', 4),
#  ('name:tzl', 4),
#  ('fuel:octane_91', 4),
#  ('fuel:octane_97', 4),
#  ('icn_ref', 4),
#  ('seamark:light:2:period', 4),
#  ('newforest:pathtype', 4),
#  ('except', 4),
#  ('building:min_height', 4),
#  ('platforms', 4),
#  ('wpt_description', 4),
#  ('tunnel:name', 4),
#  ('seamark:light:1:group', 4),
#  ('drinking_water', 4),
#  ('symbol', 4),
#  ('maxspeed:tilting', 3),
#  ('seamark:condition', 3),
#  ('section', 3),
#  ('ISO3166-1:numeric', 3),
#  ('flag', 3),
#  ('ISO3166-2', 3),
#  ('seamark:platform:category', 3),
#  ('ISO3166-1', 3),
#  ('produce', 3),
#  ('outdoor_seating', 3),
#  ('canoe', 3),
#  ('seamark:light:3:period', 3),
#  ('noexit', 3),
#  ('organic', 3),
#  ('parking:lane:both', 3),
#  ('diplomatic', 3),
#  ('roof:levels', 3),
#  ('Id', 3),
#  ('handrail:right', 3),
#  ('waste_basket', 3),
#  ('contact:fax', 3),
#  ('start_date', 3),
#  ('ISO3166-1:alpha2', 3),
#  ('seamark:buoy_lateral:colour_pattern', 3),
#  ('ship', 3),
#  ('hires:imagery', 3),
#  ('social_facility:for', 3),
#  ('ISO3166-1:alpha3', 3),
#  ('fuel:octane_92', 3),
#  ('parking:lane:right', 3),
#  ('bridge_name', 3),
#  ('name:kab', 3),
#  ('motorboat', 3),
#  ('sloped_curb', 3),
#  ('highspeed', 3),
#  ('maxweight:conditional', 3),
#  ('bicycle_road', 3),
#  ('destination:ref', 3),
#  ('fuel:octane_100', 3),
#  ('steps', 3),
#  ('artwork_type', 3),
#  ('island', 3),
#  ('diet', 3),
#  ('handrail:center', 2),
#  ('seamark:light:2:group', 2),
#  ('name_2', 2),
#  ('maxwidth', 2),
#  ('disputed', 2),
#  ('cargo', 2),
#  ('addr:state', 2),
#  ('name:si', 2),
#  ('name:zh_pinyin', 2),
#  ('name:kbd', 2),
#  ('wikipedia:en', 2),
#  ('handrail:left', 2),
#  ('seamark:landmark:function', 2),
#  ('addr:complex', 2),
#  ('generator:source', 2),
#  ('addr:floor', 2),
#  ('proposed:active_traffic_management', 2),
#  ('buoy:colour', 2),
#  ('light', 2),
#  ('lines', 2),
#  ('raceway', 2),
#  ('conveying', 2),
#  ('naptan:Bearing', 2),
#  ('name:ak', 2),
#  ('full_name', 2),
#  ('loc_name', 2),
#  ('mtb:scale:uphill', 2),
#  ('Type', 2),
#  ('name:cbk-zam', 2),
#  ('seamark:beacon_isolated_danger:shape', 2),
#  ('name:za', 2),
#  ('wheelchair_toilet', 2),
#  ('W125A', 2),
#  ('W125B', 2),
#  ('traffic_signals:sound', 2),
#  ('payment:mastercard', 2),
#  ('size', 2),
#  ('artist_name', 2),
#  ('population', 2),
#  ('wikipedia:de', 2),
#  ('addr:subdistrict', 2),
#  ('seamark:pile:category', 2),
#  ('hires', 2),
#  ('placement', 2),
#  ('abbreviation', 2),
#  ('W111', 2),
#  ('name:tet', 2),
#  ('name:pag', 2),
#  ('name:lo', 2),
#  ('name:rm', 2),
#  ('name:en3', 2),
#  ('W113', 2),
#  ('W112', 2),
#  ('name:new', 2),
#  ('W115', 2),
#  ('W114', 2),
#  ('name:he1', 2),
#  ('name:he2', 2),
#  ('name:he3', 2),
#  ('name:hsb', 2),
#  ('seamark:gate:water_level', 2),
#  ('seamark', 2),
#  ('demolished:tracktype', 2),
#  ('bollard', 2),
#  ('addr:interpolation', 2),
#  ('parking:condition:right', 2),
#  ('property', 2),
#  ('alt_name:en', 2),
#  ('units', 2),
#  ('payment:visa', 2),
#  ('intermittent', 2),
#  ('lesbian', 2),
#  ('name:en4', 2),
#  ('name:en5', 2),
#  ('name:dz', 2),
#  ('healthcare:speciality', 2),
#  ('name:chr', 2),
#  ('escalators', 2),
#  ('addr:flats', 2),
#  ('amenity_1', 2),
#  ('demolished:highway', 2),
#  ('local_ref', 2),
#  ('addr:full', 2),
#  ('memorial:type', 2),
#  ('tomb', 2),
#  ('complete', 2),
#  ('name:pap', 2),
#  ('dispensing', 2),
#  ('theatre:type', 2),
#  ('official_name', 2),
#  ('floating', 2),
#  ('proposed:maxspeed', 2),
#  ('self_service', 2),
#  ('buoy', 2),
#  ('T134', 1),
#  ('W212', 1),
#  ('W213', 1),
#  ('W214', 1),
#  ('W215', 1),
#  ('W216', 1),
#  ('W217', 1),
#  ('T2043', 1),
#  ('T2042', 1),
#  ('T2041', 1),
#  ('contact:yelp', 1),
#  ('T712', 1),
#  ('T713', 1),
#  ('SPI', 1),
#  ('automated', 1),
#  ('addr:block', 1),
#  ('T22617', 1),
#  ('user_defined_other', 1),
#  ('gantry:type', 1),
#  ('ele:msl', 1),
#  ('W1414A', 1),
#  ('scout', 1),
#  ('fireplace', 1),
#  ('W315A', 1),
#  ('source:name', 1),
#  ('W315B', 1),
#  ('bridge:structure', 1),
#  ('seamark:hulk:category', 1),
#  ('T1024-5', 1),
#  ('T222', 1),
#  ('W5A15', 1),
#  ('W5A19', 1),
#  ('Funan', 1),
#  ('seamark:light:3:group', 1),
#  ('T734', 1),
#  ('core', 1),
#  ('T2125', 1),
#  ('T725', 1),
#  ('capital', 1),
#  ('T2044', 1),
#  ('access:lanes', 1),
#  ('healthcare', 1),
#  ('T1035-6', 1),
#  ('name:stq', 1),
#  ('T3A03-04', 1),
#  ('name:bm', 1),
#  ('landcover', 1),
#  ('T11A502', 1),
#  ('official_name:sv', 1),
#  ('name:frr', 1),
#  ('passengers', 1),
#  ('substance', 1),
#  ('T11A311', 1),
#  ('T11A317', 1),
#  ('T11A314', 1),
#  ('Avg_Horz_P', 1),
#  ('advertising', 1),
#  ('W415D', 1),
#  ('is_in:iso_3166_2', 1),
#  ('W415A', 1),
#  ('W415C', 1),
#  ('official_name:el', 1),
#  ('surveillance:type', 1),
#  ('official_name:et', 1),
#  ('official_name:eu', 1),
#  ('T921A', 1),
#  ('W414A/B', 1),
#  ('T2126', 1),
#  ('SMA', 1),
#  ('osmc:symbol', 1),
#  ('W1212', 1),
#  ('SHAPE_Leng', 1),
#  ('T901-3', 1),
#  ('disused:highway', 1),
#  ('T1723', 1),
#  ('T1722', 1),
#  ('T1721', 1),
#  ('lwn', 1),
#  ('T2123', 1),
#  ('W1111B', 1),
#  ('W1111A', 1),
#  ('T2251', 1),
#  ('W1218', 1),
#  ('wikipedia:id', 1),
#  ('T3A415', 1),
#  ('hires:checkdate', 1),
#  ('T22515', 1),
#  ('T211', 1),
#  ('fuel:GTL_diesel', 1),
#  ('T213', 1),
#  ('T212', 1),
#  ('country_code_fips', 1),
#  ('FolderPath', 1),
#  ('LT5A', 1),
#  ('T11A504', 1),
#  ('W3110/A', 1),
#  ('LT5B', 1),
#  ('T1451-2/4-6', 1),
#  ('ncn_ref', 1),
#  ('Avg_Vert_P', 1),
#  ('T16213', 1),
#  ('T16214', 1),
#  ('W1421', 1),
#  ('W416B', 1),
#  ('wikipedia:fr', 1),
#  ('name:nap', 1),
#  ('service_times', 1),
#  ('name:zea', 1),
#  ('T11A601', 1),
#  ('T2055-6', 1),
#  ('power_source', 1),
#  ('W413A/B', 1),
#  ('W221', 1),
#  ('country_code_iso3166_1_alpha_2', 1),
#  ('cost:coffee', 1),
#  ('official_name:lb', 1),
#  ('capacity:women', 1),
#  ('fuel:cng', 1),
#  ('tiger:county', 1),
#  ('road', 1),
#  ('official_name:lt', 1),
#  ('reg_ref', 1),
#  ('T723', 1),
#  ('maintenance', 1),
#  ('T931', 1),
#  ('name:tw', 1),
#  ('name:ti', 1),
#  ('name:to', 1),
#  ('T1481', 1),
#  ('T934', 1),
#  ('ramp:wheelchair', 1),
#  ('attraction', 1),
#  ('T2051-2', 1),
#  ('addr:housename:zh', 1),
#  ('camera:mount', 1),
#  ('scuba_diving:rental', 1),
#  ('W317', 1),
#  ('T2054', 1),
#  ('T2053', 1),
#  ('Bandar', 1),
#  ('T1481A', 1),
#  ('T1481B', 1),
#  ('T2033-7', 1),
#  ('food', 1),
#  ('addr:door', 1),
#  ('city_served', 1),
#  ('T251', 1),
#  ('W1001', 1),
#  ('T11A403A', 1),
#  ('seamark:harbour:category', 1),
#  ('turn:lanes:backward', 1),
#  ('MLT1', 1),
#  ('T135', 1),
#  ('old_name:zh', 1),
#  ('category', 1),
#  ('name:zu', 1),
#  ('W1213', 1),
#  ('wetap:status', 1),
#  ('T1032-3/4', 1),
#  ('T221', 1),
#  ('T223', 1),
#  ('T724', 1),
#  ('T721', 1),
#  ('T722', 1),
#  ('T2128', 1),
#  ('x', 1),
#  ('T2127', 1),
#  ('T11A309A', 1),
#  ('W1112A', 1),
#  ('name:ch', 1),
#  ('abandoned:highway', 1),
#  ('name:tpi', 1),
#  ('ele:source', 1),
#  ('rank', 1),
#  ('name:historic:1968', 1),
#  ('wikipedia:ru', 1),
#  ('W5A210', 1),
#  ('W5A211', 1),
#  ('management', 1),
#  ('T1021', 1),
#  ('Line_ID', 1),
#  ('W511F', 1),
#  ('Worst_Vert', 1),
#  ('Shape_Area', 1),
#  ('est_width', 1),
#  ('camera:type', 1),
#  ('service:bicycle:pump', 1),
#  ('W5A21C', 1),
#  ('ncn', 1),
#  ('GNSS_3DLen', 1),
#  ('official_name:ru', 1),
#  ('target', 1),
#  ('name:srn', 1),
#  ('roundtrip', 1),
#  ('T112-5', 1),
#  ('ref:ibnr', 1),
#  ('T2031-2', 1),
#  ('fuel:electricity', 1),
#  ('name:iu', 1),
#  ('building_1', 1),
#  ('destination:lanes', 1),
#  ('T833', 1),
#  ('name:historic:1981', 1),
#  ('W3112A', 1),
#  ('T11A101', 1),
#  ('ref_name', 1),
#  ('Name', 1),
#  ('day_on', 1),
#  ('capacity:car_sharing', 1),
#  ('name:wa', 1),
#  ('seamark:light:1:radius', 1),
#  ('T11A411', 1),
#  ('fuel:HGV_diesel', 1),
#  ('T2124', 1),
#  ('T214', 1),
#  ('T10113', 1),
#  ('T11A201', 1),
#  ('T11A202', 1),
#  ('T11A203', 1),
#  ('T10117', 1),
#  ('disused:railway', 1),
#  ('W417', 1),
#  ('T2037A', 1),
#  ('name:ks', 1),
#  ('hour_off', 1),
#  ('wikipedia:zh', 1),
#  ('service:bicycle:rental', 1),
#  ('image', 1),
#  ('tt_ref', 1),
#  ('W3110A/B', 1),
#  ('timezone', 1),
#  ('int_network', 1),
#  ('day_off', 1),
#  ('T1481C', 1),
#  ('name:lg', 1),
#  ('multipolygon', 1),
#  ('payment:cash', 1),
#  ('name:ee', 1),
#  ('payment:credit_cards', 1),
#  ('official_name:vi', 1),
#  ('history', 1),
#  ...]

# %%
# keys that start with address
[x.split(':') for x in keys_descr['keys'].keys() if x.split(':')[0] == 'addr']
# Out:
# [['addr', 'block'],
#  ['addr', 'street'],
#  ['addr', 'state'],
#  ['addr', 'complex'],
#  ['addr', 'floor'],
#  ['addr', 'housenumber'],
#  ['addr', 'housename', 'zh'],
#  ['addr', 'door'],
#  ['addr', 'housename'],
#  ['addr', 'place'],
#  ['addr', 'suburb'],
#  ['addr', 'subdistrict'],
#  ['addr', 'postcode'],
#  ['addr', 'unit'],
#  ['addr', 'interpolation'],
#  ['addr', 'town'],
#  ['addr', 'name'],
#  ['addr', 'country'],
#  ['addr', 'city'],
#  ['addr', 'flats'],
#  ['addr', 'full'],
#  ['addr', 'housenumber_1']]

# %% [markdown]
# ### Values
# > I am now saving the parsed data without any cleaning into mongo so the find and aggregation tools can be utilized to understand data content

# %%
# Data schema

# {
# "id": "2406124091",
# "type: "node",
# "visible":"true",
# "created": {
#           "version":"2",
#           "changeset":"17206049",
#           "timestamp":"2013-08-03T16:43:42Z",
#           "user":"linuxUser16",
#           "uid":"1219059"
#         },
# "pos": [41.9757030, -87.6921867],
# "address": {
#           "housenumber": "5157",
#           "postcode": "60625",
#           "street": "North Lincoln Ave"
#         },
# "amenity": "restaurant",
# "cuisine": "mexican",
# "name": "La Cabana De Don Luis",
# "phone": "1 (773)-271-5176"
# }


CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        node['id'] = element.attrib['id']
        node['type'] = element.tag
        if 'visible' in element.attrib:
            node['visible'] = element.attrib['visible']
        node['created'] = {}
        for c in CREATED:
            node['created'][c] = element.attrib[c]
        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.attrib['lat']), float(element.attrib['lon'])]
            
        for elem in element.iter('nd'):
            if 'node_refs' not in node.keys():
                node['node_refs'] = [elem.attrib['ref']]
            else:
                node['node_refs'].append(elem.attrib['ref'])
        
        for elem in element.iter('tag'):
            if problemchars.search(elem.attrib['k']):
                continue
            else:
                pieces = elem.attrib['k'].split(':')
                
                # if key is address change
                if pieces[0] == 'addr':
                    pieces[0] = 'address'
                
                if len(pieces) == 1:
                    node[pieces[0]] = {'default': elem.attrib['v']}
                    
                elif len(pieces) == 2:
                    
                    if pieces[1] == 'housenumber_1':
                        pieces[1] = 'housenumber'
                    
                    if pieces[1] == 'street':
                        value = update_name(elem.attrib['v'], mapping)
                    else:
                        value = elem.attrib['v']
                    
                    if pieces[0] not in node.keys():
                        node[pieces[0]] = {
                            pieces[1]: value
                        }
                    else:
                        node[pieces[0]].update({
                            pieces[1]: value
                        })
                else:
                    continue
        
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def process_write():
    # NOTE: if you are running this code on your computer, with a larger dataset, 
    # call the process_map procedure with pretty=False. The pretty=True option adds 
    # additional spaces to the output, making it significantly larger.
    data = process_map(filename, True)
    
    client = MongoClient("mongodb://localhost:27017")
    db = client.openmap
    
    db.mapdata_raw.insert_many(data)
        
    print str(len(data)) + " data points processed and written to db"

# %%
process_write()
# Out:
# 1134428 data points processed and written to db

# %%
# number of observations in data collection
client = MongoClient("mongodb://localhost:27017")
db = client.openmap
coll = db.mapdata_raw
coll.find().count()
# Out:
# 1134428

# %%
# number of unique users
result = coll.distinct('created.user')
len(result)
# Out:
# 1263

# %%
# number of unique users
result = coll.distinct('created.user')
len(result)

# %%
query = {'address': {'$exists': 1}}
coll.find(query).count()
# Out:
# 34015

# %%
query = {"$and": [
            {"$or": [
                {'address.city': {'$exists': 1, '$eq':'Singapore'}},
                {'address.country': {'$exists': 1, '$eq':'SG'}}
            ]},
             {'address': {'$exists': 1}}
        ]}
coll.find(query).count()
# Out:
# 11174

# %%
# count of ways and nodes
query2 = [
    {'$match': {'address': {'$exists': 1}}},
    {'$group': 
     {'_id':
      {'city': '$address.city',
       'country': '$address.country'},
      'count': { '$sum': 1 }
     }
    },
    {'$sort': {'count': -1}}
]
result = coll.aggregate(query2)
for x in result:
    pprint(x)
# Out:
# {u'_id': {u'city': u'Johor Bahru'}, u'count': 13781}
# {u'_id': {}, u'count': 8931}
# {u'_id': {u'city': u'Singapore', u'country': u'SG'}, u'count': 8200}
# {u'_id': {u'country': u'SG'}, u'count': 2124}
# {u'_id': {u'city': u'Singapore'}, u'count': 850}
# {u'_id': {u'city': u'SKUDAI'}, u'count': 35}
# {u'_id': {u'city': u'Masai'}, u'count': 13}
# {u'_id': {u'city': u'Ulu Tiram'}, u'count': 10}
# {u'_id': {u'city': u'Johor Bahru', u'country': u'MY'}, u'count': 9}
# {u'_id': {u'city': u'Batam'}, u'count': 9}
# {u'_id': {u'city': u'Batam', u'country': u'ID'}, u'count': 7}
# {u'_id': {u'city': u'Nusajaya', u'country': u'MY'}, u'count': 4}
# {u'_id': {u'city': u'Kulai'}, u'count': 3}
# {u'_id': {u'city': u'Skudai'}, u'count': 3}
# {u'_id': {u'city': u'Sembawang'}, u'count': 3}
# {u'_id': {u'city': u'singapore'}, u'count': 3}
# {u'_id': {u'city': u'Batam Kota'}, u'count': 2}
# {u'_id': {u'city': u'johor Bahru'}, u'count': 1}
# {u'_id': {u'city': u'Bandar Baru Permas Jaya'}, u'count': 1}
# {u'_id': {u'city': u'Danga Bay'}, u'count': 1}
# {u'_id': {u'city': u'Pasir Gudang, Johor'}, u'count': 1}
# {u'_id': {u'city': u'Taman Century', u'country': u'MY'}, u'count': 1}
# {u'_id': {u'city': u'Woodlands Spectrum II'}, u'count': 1}
# {u'_id': {u'city': u'82000'}, u'count': 1}
# {u'_id': {u'city': u'Pulai Johor', u'country': u'MY'}, u'count': 1}
# {u'_id': {u'city': u'Taman Ponderosa, Johor Bahru'}, u'count': 1}
# {u'_id': {u'city': u'Ang Mo Kio'}, u'count': 1}
# {u'_id': {u'city': u'Skudai', u'country': u'MY'}, u'count': 1}
# {u'_id': {u'city': u'JB'}, u'count': 1}
# {u'_id': {u'city': u'Sungai Rengit', u'country': u'MY'}, u'count': 1}
# {u'_id': {u'city': u'Bintan'}, u'count': 1}
# {u'_id': {u'city': u'01-169 Singapore'}, u'count': 1}
# {u'_id': {u'city': u'Sekupang'}, u'count': 1}
# {u'_id': {u'city': u'Permas Jaya'}, u'count': 1}
# {u'_id': {u'city': u'Kulai', u'country': u'MY'}, u'count': 1}
# {u'_id': {u'city': u'Tanjung Puteri', u'country': u'MY'}, u'count': 1}
# {u'_id': {u'city': u'Punggol'}, u'count': 1}
# {u'_id': {u'city': u'Batam Kep.Riau'}, u'count': 1}
# {u'_id': {u'city': u'Karimun'}, u'count': 1}
# {u'_id': {u'city': u'batam Kota'}, u'count': 1}
# {u'_id': {u'city': u'Gelang Patah'}, u'count': 1}
# {u'_id': {u'city': u'Holland Village'}, u'count': 1}
# {u'_id': {u'city': u'Kota Tinggi', u'country': u'MY'}, u'count': 1}
# {u'_id': {u'city': u'Batam Centre'}, u'count': 1}
# {u'_id': {u'city': u'Taman Johor Jaya'}, u'count': 1}

# %%
query = {"$and": [
            {"$or": [
                {'address.city': {'$exists': 1, '$eq':'Singapore'}},
                {'address.country': {'$exists': 1, '$eq':'SG'}}
            ]},
            {'address': {'$exists': 1}},
            {"$or": [
                {'address.street': {'$exists': 0}},
                {'address.postcode': {'$exists': 0}},
                {'address.street': {'$eq': 'null'}},
                {'address.postcode': {'$eq': 'null'}}
            ]},
        ]}
coll.find(query).count()
# Out:
# 6948

# %%
query = {"$and": [
            {"$or": [
                {'address.city': {'$exists': 1, '$eq':'Singapore'}},
                {'address.country': {'$exists': 1, '$eq':'SG'}}
            ]},
            {'address': {'$exists': 1}},
            {"$or": [
                {'address.street': {'$exists': 1}},
                {'address.postcode': {'$exists': 1}}
            ]},
        ]}
dat_in_query = coll.find(query)
dat_in = [x for x in dat_in_query]

# %%
len(dat_in)
# Out:
# 10692

# %%
dat_in[0]
# Out:
# {u'_id': ObjectId('56e3174294e1bedc4b5daf18'),
#  u'address': {u'city': u'Singapore',
#   u'country': u'SG',
#   u'housenumber': u'85',
#   u'postcode': u'198501',
#   u'street': u'Sultan Gate'},
#  u'created': {u'changeset': u'33022579',
#   u'timestamp': u'2015-08-01T01:38:25Z',
#   u'uid': u'741163',
#   u'user': u'JaLooNz',
#   u'version': u'3'},
#  u'fax': {u'default': u'+65 6299 4316'},
#  u'id': u'337171253',
#  u'name': {u'default': u'Malay Heritage Centre'},
#  u'phone': {u'default': u'+65 6391 0450'},
#  u'pos': [1.3028023, 103.85993],
#  u'tourism': {u'default': u'museum'},
#  u'type': u'node',
#  u'website': {u'default': u'http://malayheritage.org.sg/'}}

# %%
print list(db.result.find())
# Out:
# [{u'only postcode available and found': 19, u'something is wrong': 0, u'both info avail, found and match': 3411, u'both info avail, nothing found': 0, u'both info avail, found but no match': 597, u'both info avail, only streetfound': 0, u'exception': 218, u'only street available and found': 6447, u'only postcode available and not found': 0, u'both info avail, only postcode found': 0, u'_id': ObjectId('56e5e6d105482103361bbb7a')}]

# %%
new_in = db.mapdata_new.find({'type': 'both info avail, found but no match', 'address.address.street': ''})
new = [x for x in new_in]

# %%
for x in new[:10]:
    pprint(x)
# Out:
# {u'_id': ObjectId('56e5e77905482103361bbb83'),
#  u'add_post': {u'_id': ObjectId('56e3050194e1beeae6727b25'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Lower Kent Ridge Road, 31, Singapore, Lower Kent Ridge, Pasir Panjang, Alexandra, Kent Ridge, West',
#                u'postcode': u'119078',
#                u'region1': u'West',
#                u'region2': u'Pasir Panjang, Alexandra, Kent Ridge',
#                u'region3': u'Singapore',
#                u'street': u'Lower Kent Ridge Road, 31'},
#  u'add_st': u'31 lower kent ridge road',
#  u'address': {u'_id': ObjectId('56e3174394e1bedc4b5e2b7a'),
#               u'address': {u'city': u'Singapore',
#                            u'housename': u'31 Lower Kent Ridge Rd, Singapore',
#                            u'postcode': u'119078',
#                            u'street': u'31 Lower Kent Ridge Road'},
#               u'amenity': {u'default': u'fast_food'},
#               u'created': {u'changeset': u'18266377',
#                            u'timestamp': u'2013-10-09T15:03:33Z',
#                            u'uid': u'1761022',
#                            u'user': u'jiahui',
#                            u'version': u'5'},
#               u'id': u'687602981',
#               u'name': {u'default': u'Subway'},
#               u'operator': {u'default': u'Food Junction'},
#               u'phone': {u'default': u'+65 6775 5285'},
#               u'pos': [1.2984797, 103.7751628],
#               u'type': u'node'},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbb8f'),
#  u'add_post': {u'_id': ObjectId('56e1d07c94e1beeae671a502'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Jalan Dusun, 104, Singapore, Dusun, Balestier, Bendemeer, Northeast',
#                u'postcode': u'320104',
#                u'region1': u'Northeast',
#                u'region2': u'Balestier, Bendemeer',
#                u'region3': u'Singapore',
#                u'street': u'Jalan Dusun, 104'},
#  u'add_st': {u'_id': ObjectId('56e1d2ae94e1beeae671a8e1'),
#              u'building': None,
#              u'city': u'Singapore',
#              u'full': u'Whampoa Drive, 104, Singapore, Whampoa, Balestier, Bendemeer, Northeast',
#              u'postcode': u'323104',
#              u'region1': u'Northeast',
#              u'region2': u'Balestier, Bendemeer',
#              u'region3': u'Singapore',
#              u'street': u'Whampoa Drive, 104'},
#  u'address': {u'_id': ObjectId('56e3174494e1bedc4b60d67d'),
#               u'address': {u'country': u'SG',
#                            u'housename': u'Block 104',
#                            u'housenumber': u'104',
#                            u'postcode': u'320104',
#                            u'street': u'Whampoa Drive'},
#               u'building': {u'default': u'residential'},
#               u'created': {u'changeset': u'28185674',
#                            u'timestamp': u'2015-01-16T12:43:09Z',
#                            u'uid': u'420078',
#                            u'user': u'Hydriz',
#                            u'version': u'3'},
#               u'id': u'1573744069',
#               u'pos': [1.3206663, 103.8533874],
#               u'type': u'node'},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbb90'),
#  u'add_post': {u'_id': ObjectId('56e1cf9294e1beeae671a37d'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Ah Hood Road, 101, Singapore, Ah Hood, Balestier, Bendemeer, Northeast',
#                u'postcode': u'320101',
#                u'region1': u'Northeast',
#                u'region2': u'Balestier, Bendemeer',
#                u'region3': u'Singapore',
#                u'street': u'Ah Hood Road, 101'},
#  u'add_st': {u'_id': ObjectId('56e1d2ae94e1beeae671a8e0'),
#              u'building': None,
#              u'city': u'Singapore',
#              u'full': u'Whampoa Drive, 101, Singapore, Whampoa, Balestier, Bendemeer, Northeast',
#              u'postcode': u'323101',
#              u'region1': u'Northeast',
#              u'region2': u'Balestier, Bendemeer',
#              u'region3': u'Singapore',
#              u'street': u'Whampoa Drive, 101'},
#  u'address': {u'_id': ObjectId('56e3174494e1bedc4b60d67e'),
#               u'address': {u'country': u'SG',
#                            u'housenumber': u'101',
#                            u'postcode': u'320101',
#                            u'street': u'Whampoa Drive'},
#               u'building': {u'default': u'residential', u'levels': u'25'},
#               u'created': {u'changeset': u'28185674',
#                            u'timestamp': u'2015-01-16T12:43:09Z',
#                            u'uid': u'420078',
#                            u'user': u'Hydriz',
#                            u'version': u'3'},
#               u'designation': {u'default': u'Public housing'},
#               u'id': u'1573744070',
#               u'name': {u'default': u'Block 101'},
#               u'pos': [1.3204411, 103.8537844],
#               u'type': u'node'},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbb93'),
#  u'add_post': {u'_id': ObjectId('56e0e69e94e1beeae670c643'),
#                u'building': u'Mobil Service Station',
#                u'city': u'Singapore',
#                u'full': u'Mobil Service Station, Queensway, 262, Singapore, Queensway, Queenstown, Commonwealth, Central',
#                u'postcode': u'149061',
#                u'region1': u'Central',
#                u'region2': u'Queenstown, Commonwealth',
#                u'region3': u'Singapore',
#                u'street': u'Queensway, 262'},
#  u'add_st': {u'_id': ObjectId('56e0e6a294e1beeae670c649'),
#              u'building': u'Mobil Service Station',
#              u'city': u'Singapore',
#              u'full': u'Mobil Service Station, Queensway, 622, Singapore, Queensway, Queenstown, Commonwealth, Central',
#              u'postcode': u'149067',
#              u'region1': u'Central',
#              u'region2': u'Queenstown, Commonwealth',
#              u'region3': u'Singapore',
#              u'street': u'Queensway, 622'},
#  u'address': {u'_id': ObjectId('56e3174494e1bedc4b61132a'),
#               u'address': {u'city': u'Singapore',
#                            u'housenumber': u'622',
#                            u'postcode': u'149061',
#                            u'street': u'Queensway'},
#               u'amenity': {u'default': u'fuel'},
#               u'created': {u'changeset': u'35008052',
#                            u'timestamp': u'2015-11-01T09:55:47Z',
#                            u'uid': u'3127064',
#                            u'user': u'Duane Bong',
#                            u'version': u'2'},
#               u'id': u'1652574523',
#               u'name': {u'default': u'Esso Queensway A'},
#               u'operator': {u'default': u'Esso'},
#               u'phone': {u'default': u'+65 6474 7824'},
#               u'pos': [1.3070255, 103.8024495],
#               u'type': u'node',
#               u'website': {u'default': u'http://www.esso.com.sg/'}},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbba7'),
#  u'add_post': {u'_id': ObjectId('56e0cbf394e1beeae670a7e8'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Mosque Street, 27, Singapore, Mosque, Chinatown, Central',
#                u'postcode': u'059505',
#                u'region1': u'Central',
#                u'region2': u'Chinatown',
#                u'region3': u'Singapore',
#                u'street': u'Mosque Street, 27'},
#  u'add_st': {u'_id': ObjectId('56e0cbf494e1beeae670a7eb'),
#              u'building': None,
#              u'city': u'Singapore',
#              u'full': u'Mosque Street, 30, Singapore, Mosque, Chinatown, Central',
#              u'postcode': u'059508',
#              u'region1': u'Central',
#              u'region2': u'Chinatown',
#              u'region3': u'Singapore',
#              u'street': u'Mosque Street, 30'},
#  u'address': {u'_id': ObjectId('56e3174494e1bedc4b63d735'),
#               u'address': {u'city': u'Singapore',
#                            u'country': u'SG',
#                            u'housenumber': u'30',
#                            u'postcode': u'059505',
#                            u'street': u'Mosque Street'},
#               u'created': {u'changeset': u'34255496',
#                            u'timestamp': u'2015-09-26T05:15:59Z',
#                            u'uid': u'741163',
#                            u'user': u'JaLooNz',
#                            u'version': u'4'},
#               u'email': {u'default': u'reservation@richlodging.com'},
#               u'id': u'1854611565',
#               u'internet_access': {u'default': u'wlan', u'fee': u'no'},
#               u'name': {u'default': u"Backpacker's Inn (Chinatown)"},
#               u'phone': {u'default': u'+65 6221 1239'},
#               u'pos': [1.2835734, 103.8454074],
#               u'rooms': {u'default': u'82'},
#               u'stars': {u'default': u'2'},
#               u'tourism': {u'default': u'hostel'},
#               u'type': u'node',
#               u'website': {u'default': u'http://richlodging.com/backpackers-inn-chinatown/'}},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbba8'),
#  u'add_post': {u'_id': ObjectId('56e2534e94e1beeae6724857'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Clementi Street 11, 108, Singapore, Clementi, Clementi, West',
#                u'postcode': u'120108',
#                u'region1': u'West',
#                u'region2': u'Clementi',
#                u'region3': u'Singapore',
#                u'street': u'Clementi Street 11, 108'},
#  u'add_st': u'clementi street 11',
#  u'address': {u'_id': ObjectId('56e3174594e1bedc4b645841'),
#               u'address': {u'city': u'Singapore',
#                            u'housenumber': u'Block 108',
#                            u'postcode': u'120108',
#                            u'street': u'Clementi Street 11'},
#               u'created': {u'changeset': u'34738046',
#                            u'timestamp': u'2015-10-19T17:11:51Z',
#                            u'uid': u'3127064',
#                            u'user': u'Duane Bong',
#                            u'version': u'6'},
#               u'id': u'1932320757',
#               u'name': {u'default': u'Grindelwald'},
#               u'phone': {u'default': u'+65 6775 4947'},
#               u'pos': [1.3220913, 103.7702616],
#               u'shop': {u'default': u'supermarket'},
#               u'type': u'node'},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbbab'),
#  u'add_post': {u'_id': ObjectId('56e0ccb494e1beeae670a979'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'South Bridge Road, 268, Singapore, South Bridge, Chinatown, Central',
#                u'postcode': u'058817',
#                u'region1': u'Central',
#                u'region2': u'Chinatown',
#                u'region3': u'Singapore',
#                u'street': u'South Bridge Road, 268'},
#  u'add_st': u'south bridge road',
#  u'address': {u'_id': ObjectId('56e3174594e1bedc4b645d2c'),
#               u'address': {u'city': u'Singapore',
#                            u'country': u'SG',
#                            u'housenumber': u'268A',
#                            u'postcode': u'058817',
#                            u'street': u'South Bridge Road'},
#               u'created': {u'changeset': u'34247198',
#                            u'timestamp': u'2015-09-25T16:49:37Z',
#                            u'uid': u'741163',
#                            u'user': u'JaLooNz',
#                            u'version': u'2'},
#               u'email': {u'default': u'info@theloft.com.sg'},
#               u'fax': {u'default': u'+65 6221 2152'},
#               u'id': u'1950183363',
#               u'name': {u'default': u'The Loft Pancakes & Waffles'},
#               u'phone': {u'default': u'+65 6221 2103'},
#               u'pos': [1.2818706, 103.8447869],
#               u'shop': {u'default': u'deli'},
#               u'type': u'node',
#               u'website': {u'default': u'http://theloft.com.sg/'}},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbbb2'),
#  u'add_post': {u'_id': ObjectId('56e0c57d94e1beeae670a092'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Middle Road, 31, Singapore, Middle, Bugis, Victoria Street, Rochor, Central',
#                u'postcode': u'188995',
#                u'region1': u'Central',
#                u'region2': u'Bugis, Victoria Street, Rochor',
#                u'region3': u'Singapore',
#                u'street': u'Middle Road, 31'},
#  u'add_st': {u'_id': ObjectId('56e0c55794e1beeae670a04b'),
#              u'building': None,
#              u'city': u'Singapore',
#              u'full': u'Liang Seah Street, 31, Singapore, Liang Seah, Bugis, Victoria Street, Rochor, Central',
#              u'postcode': u'189052',
#              u'region1': u'Central',
#              u'region2': u'Bugis, Victoria Street, Rochor',
#              u'region3': u'Singapore',
#              u'street': u'Liang Seah Street, 31'},
#  u'address': {u'_id': ObjectId('56e3174594e1bedc4b64e705'),
#               u'address': {u'city': u'Singapore',
#                            u'country': u'SG',
#                            u'housenumber': u'31',
#                            u'postcode': u'188995',
#                            u'street': u'Seah Street'},
#               u'created': {u'changeset': u'19766610',
#                            u'timestamp': u'2014-01-02T13:44:19Z',
#                            u'uid': u'741163',
#                            u'user': u'JaLooNz',
#                            u'version': u'3'},
#               u'id': u'2142181976',
#               u'name': {u'default': u'Hotel 81 Bugis'},
#               u'pos': [1.2968558, 103.8557635],
#               u'tourism': {u'default': u'hotel'},
#               u'type': u'node'},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbbb3'),
#  u'add_post': {u'_id': ObjectId('56e3096094e1beeae672832f'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Yuan Ching Road, 134D, Singapore, Yuan Ching, Taman Jurong, West',
#                u'postcode': u'618656',
#                u'region1': u'West',
#                u'region2': u'Taman Jurong',
#                u'region3': u'Singapore',
#                u'street': u'Yuan Ching Road, 134D'},
#  u'add_st': u'yuan ching road',
#  u'address': {u'_id': ObjectId('56e3174594e1bedc4b650cc5'),
#               u'address': {u'city': u'Singapore',
#                            u'door': u'#02-201',
#                            u'housenumber': u'134D',
#                            u'postcode': u'618656',
#                            u'street': u'Yuan Ching Road'},
#               u'building': {u'default': u'residential'},
#               u'created': {u'changeset': u'15392366',
#                            u'timestamp': u'2013-03-17T08:21:31Z',
#                            u'uid': u'67592',
#                            u'user': u'Sybren',
#                            u'version': u'1'},
#               u'id': u'2206339911',
#               u'name': {u'default': u'Scholars Residence'},
#               u'pos': [1.3406712, 103.722014],
#               u'type': u'node'},
#  u'type': u'both info avail, found but no match'}
# {u'_id': ObjectId('56e5e77905482103361bbbbc'),
#  u'add_post': {u'_id': ObjectId('56e0d79f94e1beeae670bdd9'),
#                u'building': None,
#                u'city': u'Singapore',
#                u'full': u'Bayfront Avenue, 1, Singapore, Bayfront, Marina South, Central',
#                u'postcode': u'018971',
#                u'region1': u'Central',
#                u'region2': u'Marina South',
#                u'region3': u'Singapore',
#                u'street': u'Bayfront Avenue, 1'},
#  u'add_st': u'bayfront avebue',
#  u'address': {u'_id': ObjectId('56e3174594e1bedc4b65dfb0'),
#               u'address': {u'city': u'Singapore',
#                            u'housenumber': u'1',
#                            u'postcode': u'018971',
#                            u'street': u'Bayfront Avebue',
#                            u'unit': u'Marina Bay Sands North Tower'},
#               u'amenity': {u'default': u'bar'},
#               u'created': {u'changeset': u'35013831',
#                            u'timestamp': u'2015-11-01T14:56:12Z',
#                            u'uid': u'3127064',
#                            u'user': u'Duane Bong',
#                            u'version': u'5'},
#               u'food': {u'default': u'yes'},
#               u'id': u'2424592455',
#               u'name': {u'default': u'C\xc9 LA VI'},
#               u'outdoor_seating': {u'default': u'yes'},
#               u'phone': {u'default': u'+65 6688 7688'},
#               u'pos': [1.2846154, 103.860933],
#               u'smoking': {u'default': u'yes'},
#               u'type': u'node',
#               u'website': {u'default': u'http://sg.celavi.com/'}},
#  u'type': u'both info avail, found but no match'}

# %%
set([(x['address']['address']['street'], x['add_post']['full']) for x in new])
# Out:
# {(u'1 Pasir Ris Close',
#   u'Pasir Ris Ntuc Resort, Pasir Ris Close, 1, Singapore, Pasir Ris, Pasir Ris, East'),
#  (u'140 Maxwell Road',
#   u'Tanjong Pagar Mrt Station, Maxwell Road, 120, Singapore, Maxwell, Robinson Road, Shenton Way, Central'),
#  (u'31 Lower Kent Ridge Road',
#   u'Lower Kent Ridge Road, 31, Singapore, Lower Kent Ridge, Pasir Panjang, Alexandra, Kent Ridge, West'),
#  (u'535 Clementi Road',
#   u'Ngee Ann Polytechnic, Clementi Road, 535, Singapore, Clementi, Bukit Timah, King Albert Park, North'),
#  (u'Alexandra Road',
#   u'Alexandra Road, 991B, Singapore, Alexandra, Pasir Panjang, Alexandra, Kent Ridge, West'),
#  (u'Alexandra Road',
#   u'Alexandra Technopark, Alexandra Road, 438B, Singapore, Alexandra, Pasir Panjang, Alexandra, Kent Ridge, West'),
#  (u'Amoy Street',
#   u'Amoy Street, 102, Singapore, Amoy, Robinson Road, Shenton Way, Central'),
#  (u'Amoy Street',
#   u'Amoy Street, 130, Singapore, Amoy, Raffles Place, Central'),
#  (u'Amoy Street',
#   u'Amoy Street, 23, Singapore, Amoy, Robinson Road, Shenton Way, Central'),
#  (u'Amoy Street',
#   u'Amoy Street, 92D, Singapore, Amoy, Robinson Road, Shenton Way, Central'),
#  (u'Ang Mo Kio Avenue 6',
#   u'Ang Mo Kio Avenue 6, 700A, Singapore, Ang Mo Kio, Ang Mo Kio, Northeast'),
#  (u'Ang Mo Kio Avenue 6',
#   u'Ang Mo Kio Avenue 8, 710, Singapore, Ang Mo Kio, Ang Mo Kio, Northeast'),
#  (u'Ang Mo Kio Electronics Park Road',
#   u'Ang Mo Kio Industrial Park 3, 10, Singapore, Ang Mo Kio, Ang Mo Kio, Northeast'),
#  (u'Ann Siang Road',
#   u'Ann Siang Road, 7, Singapore, Ann Siang, Robinson Road, Shenton Way, Central'),
#  (u'Anson Road',
#   u'Springleaf Tower, Anson Road, 3, Singapore, Anson, Prince Edward, Anson Road, Central'),
#  (u'Ardmore Park',
#   u'Ardmore Point, Ardmore Park, 1A, Singapore, Ardmore, Bukit Timah, Stevens Road, North'),
#  (u'Bayfront Avebue',
#   u'Bayfront Avenue, 1, Singapore, Bayfront, Marina South, Central'),
#  (u'Bayfront Avenue',
#   u'Bayfront Avenue, 10, Singapore, Bayfront, Marina South, Central'),
#  (u'Beach Road',
#   u'Gateway East, Beach Road, 152, Singapore, Beach, Bugis, Victoria Street, Rochor, Central'),
#  (u'Beach Road',
#   u'The Concourse, Beach Road, 300, Singapore, Beach, Kampong Glam, Beach Road, Central'),
#  (u'Bedok North Street 2',
#   u'Bedok North Road, 119, Singapore, Bedok, Bedok, Chai Chee, East'),
#  (u'Bedok Reservoir Road',
#   u'Bedok Reservoir Road, 609, Singapore, Bedok Reservoir, Bedok Reservoir, East'),
#  (u'Bedok Reservoir Road',
#   u'Bedok Reservoir Road, 613, Singapore, Bedok Reservoir, Bedok Reservoir, East'),
#  (u'Bedok Reservoir Road',
#   u'Bedok Reservoir Road, 623, Singapore, Bedok Reservoir, Bedok Reservoir, East'),
#  (u'Bedok South Avenue 3',
#   u'Telok Kurau Primary School, Bedok Reservoir Road, 50, Singapore, Bedok Reservoir, Bedok Reservoir, East'),
#  (u'Begonia Crescent',
#   u'Hock Swee Hill, Begonia Crescent, 8, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Begonia Drive, 35A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Begonia Drive, 37A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 1A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 1B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 2A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 2B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 2C, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 2D, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 2E, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 3A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 3B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 4A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 4B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 5A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 5B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 6A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 6B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 7A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 7B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 8A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 8B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 8C, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 8D, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 8E, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 9A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Fanta Garden, Begonia Drive, 9B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 10A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 10B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 10C, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 10D, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 10E, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 10F, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 10G, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 33, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Drive',
#   u'Hock Swee Hill, Begonia Drive, 35, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Lane',
#   u'Kelulut Hill, 99, Singapore, Kelulut, Yio Chu Kang, Northeast'),
#  (u'Begonia Road',
#   u'Begonia Road, 4A, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Begonia Road',
#   u'Begonia Road, 4B, Singapore, Begonia, Yio Chu Kang, Northeast'),
#  (u'Bishan Street 14',
#   u'Bishan Street 14, 9A, Singapore, Bishan, Bishan, Thomson Road, Northeast'),
#  (u'Bishan Street 22',
#   u'Bishan Street 22, 233, Singapore, Bishan, Bishan, Thomson Road, Northeast'),
#  (u'Boat Quay', u'Boat Quay, 30, Singapore, Boat, Raffles Place, Central'),
#  (u'Boat Quay',
#   u'South Bridge Road, 88, Singapore, South Bridge, Chinatown, Central'),
#  (u'Boon Tat Street',
#   u'Boon Tat Street, 23, Singapore, Boon Tat, Robinson Road, Shenton Way, Central'),
#  (u'Boon Tat Street',
#   u'Boon Tat Street, 7, Singapore, Boon Tat, Robinson Road, Shenton Way, Central'),
#  (u'Brooke Road',
#   u'Katong Plaza, Brooke Road, 1, Singapore, Brooke, Katong, Joo Chiat, East'),
#  (u'Bukit Batok East Avenue 5',
#   u'Bukit Batok East Avenue 5, 233, Singapore, Bukit Batok, Bukit Batok, Bukit Gombak, West'),
#  (u'Bukit Merah Central',
#   u'Bukit Merah Central, 3500A, Singapore, Bukit Merah, Redhill, Bukit Merah, Alexandra, Central'),
#  (u'Burghley Drive',
#   u'Chij Our Lady of Good Counsel, Burghley Drive, 2C, Singapore, Burghley, Serangoon Central, Serangoon Gardens, Northeast'),
#  (u'Cantonment Close',
#   u'Tanjong Pagar Plaza, 8, Singapore, Tanjong Pagar, Tanjong Pagar, Central'),
#  (u'Cantonment Road',
#   u'The Pinnacle@duxton, Cantonment Road, 1A, Singapore, Cantonment, Tanjong Pagar, Central'),
#  (u'Cantonment Road',
#   u'The Pinnacle@duxton, Cantonment Road, 1B, Singapore, Cantonment, Tanjong Pagar, Central'),
#  (u'Cantonment Road',
#   u'The Pinnacle@duxton, Cantonment Road, 1C, Singapore, Cantonment, Tanjong Pagar, Central'),
#  (u'Cantonment Road',
#   u'The Pinnacle@duxton, Cantonment Road, 1D, Singapore, Cantonment, Tanjong Pagar, Central'),
#  (u'Cantonment Road',
#   u'The Pinnacle@duxton, Cantonment Road, 1E, Singapore, Cantonment, Tanjong Pagar, Central'),
#  (u'Cantonment Road',
#   u'The Pinnacle@duxton, Cantonment Road, 1F, Singapore, Cantonment, Tanjong Pagar, Central'),
#  (u'Cantonment Road',
#   u'The Pinnacle@duxton, Cantonment Road, 1G, Singapore, Cantonment, Tanjong Pagar, Central'),
#  (u'Chai Chee Street',
#   u'Chai Chee Drive, 55, Singapore, Chai Chee, Bedok, Chai Chee, East'),
#  (u'Chang Charn Road',
#   u'Chang Charn Road, 1, Singapore, Chang Charn, Redhill, Bukit Merah, Alexandra, Central'),
#  (u'Changi Road',
#   u'Great Eastern House, Beach Road, 49, Singapore, Beach, Bugis, Victoria Street, Rochor, Central'),
#  (u'Chin Swee Road',
#   u'Chin Swee Road, 175A, Singapore, Chin Swee, Outram Road, Tiong Bahru, Central'),
#  (u'Chin Swee Road',
#   u'Seacare Building, Chin Swee Road, 52, Singapore, Chin Swee, Outram Road, Tiong Bahru, Central'),
#  (u'Choa Chu Kang Cresent',
#   u'Unity Primary School, Choa Chu Kang Crescent, 21, Singapore, Choa Chu Kang, Yew Tee, Choa Chu Kang, North'),
#  (u'Chua Chu Kang Street 52',
#   u'Yew Tee Community Building, Choa Chu Kang Street 52, 20, Singapore, Choa Chu Kang, Yew Tee, Choa Chu Kang, North'),
#  (u'Chuan Hoe Avenue',
#   u'Chuan Hoe Avenue, 825B, Singapore, Chuan Hoe, Sengkang, Buangkok, Northeast'),
#  (u'Circular Road',
#   u'Circular Road, 12, Singapore, Circular, Raffles Place, Central'),
#  (u'Circular Road',
#   u'Lex Loci, Circular Road, 9, Singapore, Circular, Raffles Place, Central'),
#  (u'Clementi Road',
#   u'Clementi Road, 107, Singapore, Clementi, Clementi, West'),
#  (u'Clementi Road',
#   u'Clementi Road, 93A, Singapore, Clementi, Clementi, West'),
#  (u'Clementi Road',
#   u'Ngee Ann Polytechnic, Clementi Road, 535, Singapore, Clementi, Bukit Timah, King Albert Park, North'),
#  (u'Clementi Street 11',
#   u'Clementi Street 11, 108, Singapore, Clementi, Clementi, West'),
#  (u'Clementi Street 11',
#   u'Clementi Street 11, 109, Singapore, Clementi, Clementi, West'),
#  (u'Clementi Street 12',
#   u'Clementi Street 12, 105, Singapore, Clementi, Clementi, West'),
#  (u'Clementi Street 12',
#   u'Clementi Street 12, 106, Singapore, Clementi, Clementi, West'),
#  (u'Coleman Street',
#   u'Masonic Hall, Coleman Street, 23A, Singapore, Coleman, Central Fire Station, Hill Street, Central'),
#  (u'Collyer Quay',
#   u'Collyer Quay, 70, Singapore, Collyer, Raffles Place, Central'),
#  (u'Connaught Drive',
#   u'Singapore Recreation Club, Connaught Drive, B, Singapore, Connaught, Central Fire Station, Hill Street, Central'),
#  (u'Cross Street',
#   u'Marsh & Mclennan Centre, Cross Street, 18, Singapore, Cross, Raffles Place, Central'),
#  (u'Cross Street',
#   u'Pwc Building, Cross Street, 8, Singapore, Cross, Raffles Place, Central'),
#  (u'Cross Street',
#   u'South Bridge Court, Cross Street, 22, Singapore, Cross, Raffles Place, Central'),
#  (u'Dalhousie Lane',
#   u'Dalhousie Lane, 6, Singapore, Dalhousie, Lavender, Jalan Besar, Central'),
#  (u'Dedap Place',
#   u'Tuan Sing Park, Yio Chu Kang Road, 347, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Dedap Place',
#   u'Tuan Sing Park, Yio Chu Kang Road, 347B, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Dedap Place',
#   u'Tuan Sing Park, Yio Chu Kang Road, 349A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Dedap Place',
#   u'Tuan Sing Park, Yio Chu Kang Road, 349B, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Dedap Place',
#   u'Tuan Sing Park, Yio Chu Kang Road, 349C, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Dempsey Road',
#   u'Dempsey Road, 25A, Singapore, Dempsey, Tanglin Road, River Valley, Central'),
#  (u'Dover Close',
#   u'Anglo-chinese Junior College, Dover Close East, 25, Singapore, Dover, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'Dover Crescent',
#   u'Dover Crescent, 28A, Singapore, Dover, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'Dover Crescent',
#   u'Dover Crescent, 28B, Singapore, Dover, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'Dover Crescent',
#   u'Dover Crescent, 28C, Singapore, Dover, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'Dover Crescent',
#   u'Dover Crescent, 28D, Singapore, Dover, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'Dover Crescent',
#   u'Multi Storey Car Park, Dover Crescent, 28, Singapore, Dover, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'Duchess Road',
#   u"King's Garden, King's Walk, 17, Singapore, King's, Bukit Timah, Farrer Road, Coronation Road, West"),
#  (u'Dunman Road',
#   u"Tanjong Katong Girl's School, Dunman Lane, 20, Singapore, Dunman, Katong, Tanjong Rhu, East"),
#  (u'Duxton Hill', u'Craig Road, 38, Singapore, Craig, Tanjong Pagar, Central'),
#  (u'Duxton Road',
#   u'Duxton Road, 17, Singapore, Duxton, Tanjong Pagar, Central'),
#  (u'East Coast Road',
#   u"St. Patrick's Secondary School, East Coast Road, 490, Singapore, East Coast, Katong, Joo Chiat, East"),
#  (u'East Coast Road #03-09',
#   u'Katong Mall, East Coast Road, 112, Singapore, East Coast, Katong, Joo Chiat, East'),
#  (u'East Coast Road #03-14',
#   u'Katong Mall, East Coast Road, 112, Singapore, East Coast, Katong, Joo Chiat, East'),
#  (u'Edgefield Plains',
#   u'Edgedale Plains, 61, Singapore, Edgedale, Punggol, Northeast'),
#  (u'Eu Chin Street',
#   u'Tiong Bahru Community Centre, Eu Chin Street, 67A, Singapore, Eu Chin, Outram Road, Tiong Bahru, Central'),
#  (u'Fairway Drive',
#   u'Fairways Drive, 60, Singapore, Fairways, Bukit Timah, old Turf Club, North'),
#  (u'Fernvale Road',
#   u'Fernvale Road, 443C, Singapore, Fernvale, Seletar, Northeast'),
#  (u'Fernvale Road',
#   u'Sengkang West Avenue, 21, Singapore, Sengkang, Seletar, Northeast'),
#  (u'Gelyang Bahru',
#   u'Geylang Bahru, 59B, Singapore, Geylang Bahru, Geylang Bahru, Northeast'),
#  (u'Ghim Moh Road',
#   u'Ghim Moh Road, 19, Singapore, Ghim Moh, Holland Road, Ghim Moh, West'),
#  (u'Ghim Moh Road',
#   u'Ghim Moh Road, 21, Singapore, Ghim Moh, Holland Road, Ghim Moh, West'),
#  (u'Ghim Moh Road',
#   u'Ghim Moh Road, 7, Singapore, Ghim Moh, Holland Road, Ghim Moh, West'),
#  (u'Ghim Moh Road',
#   u'Ghim Moh Road, 8, Singapore, Ghim Moh, Holland Road, Ghim Moh, West'),
#  (u'Gopeng Street',
#   u'Icon, Gopeng Street, 10, Singapore, Gopeng, Prince Edward, Anson Road, Central'),
#  (u'Grange Road',
#   u'Omni Marco Polo Hotel, Tanglin Road, 247, Singapore, Tanglin, Tanglin Road, River Valley, Central'),
#  (u'Hamilton Road',
#   u'Hamilton Road, 7, Singapore, Hamilton, Lavender, Jalan Besar, Central'),
#  (u'Havelock Road',
#   u'Central Square, Havelock Road, 20, Singapore, Havelock, Chinatown, Central'),
#  (u'Holland Road',
#   u'Allsworth Park, Holland Road, 361, Singapore, Holland, Holland Road, Ghim Moh, West'),
#  (u'Hong Kong Street',
#   u'Hongkong Street, 18, Singapore, Hongkong, Chinatown, Central'),
#  (u'Hong Kong Street',
#   u'Hongkong Street, 20, Singapore, Hongkong, Chinatown, Central'),
#  (u'Hong Kong Street',
#   u'Hongkong Street, 28, Singapore, Hongkong, Chinatown, Central'),
#  (u'Hong Kong Street',
#   u'Hongkong Street, 33, Singapore, Hongkong, Chinatown, Central'),
#  (u'Hong Kong Street',
#   u'Hongkong Street, 38, Singapore, Hongkong, Chinatown, Central'),
#  (u'Hong Kong Street',
#   u'Hongkong Street, 5, Singapore, Hongkong, Chinatown, Central'),
#  (u'Hougang Street 51',
#   u'Multi Storey Car Park, Hougang Street 51, 566A, Singapore, Hougang, Hougang, Serangoon, Yio Chu Kang, Kovan, Northeast'),
#  (u'Irrawaddy Road',
#   u'New Phoenix Park, Irrawaddy Road, 28, Singapore, Irrawaddy, Balestier, Bendemeer, Northeast'),
#  (u'Jalan Kenarah',
#   u'Jalan Kenarah, 2A, Singapore, Kenarah, Yio Chu Kang, Northeast'),
#  (u'Jalan Kenarah',
#   u'Jalan Kenarah, 2F, Singapore, Kenarah, Yio Chu Kang, Northeast'),
#  (u'Jalan Papan', u'Jalan Papan, 2D, Singapore, Papan, Taman Jurong, West'),
#  (u'Jalan Papan', u'Jalan Papan, 5A, Singapore, Papan, Taman Jurong, West'),
#  (u'Jalan Rajah',
#   u'Jalan Rajah, 92, Singapore, Rajah, Balestier, Bendemeer, Northeast'),
#  (u'Jalan Rajah, #01-01, Zhong Shan Park,',
#   u'Jalan Rajah, 1, Singapore, Rajah, Balestier, Bendemeer, Northeast'),
#  (u'Jalan Tari Payong',
#   u'Jalan Tari Payong, 12A, Singapore, Tari Payong, Seletar, Northeast'),
#  (u'Jalan Tari Payong',
#   u'Jalan Tari Payong, 18A, Singapore, Tari Payong, Seletar, Northeast'),
#  (u'Jalan Tari Serimpi',
#   u'Jalan Tari Serimpi, 1B, Singapore, Tari Serimpi, Seletar, Northeast'),
#  (u'Jalan Tari Serimpi',
#   u'Jalan Tari Serimpi, 1C, Singapore, Tari Serimpi, Seletar, Northeast'),
#  (u'Jiak Chuan Road',
#   u'Jiak Chuan Road, 8, Singapore, Jiak Chuan, Tanjong Pagar, Central'),
#  (u'Jln Bkt Ho Swee',
#   u'Jalan Bukit Ho Swee, 355, Singapore, Bukit Ho Swee, Outram Road, Tiong Bahru, Central'),
#  (u'Jurong West Avenue 3',
#   u'Jurong West Avenue 3, 276B, Singapore, Jurong, Jurong West, Lakeside, Boon Lay, West'),
#  (u'Jurong West Avenue 5',
#   u'Jurong West Street 81, 836, Singapore, Jurong, Jurong West, Lakeside, Boon Lay, West'),
#  (u'Jurong West Street 61',
#   u'Jurong Primary School, Jurong East Street 32, 320, Singapore, Jurong, Jurong East, West'),
#  (u'Jurong West Street 64',
#   u'Jurong West Street 64, 665A, Singapore, Jurong, Jurong West, Lakeside, Boon Lay, West'),
#  (u'Jurong West Street 91',
#   u'Jurong West Street 92, 932, Singapore, Jurong, Jurong West, Lakeside, Boon Lay, West'),
#  (u'Jurong West Street 91',
#   u'Jurong West Street 92, 960, Singapore, Jurong, Jurong West, Lakeside, Boon Lay, West'),
#  (u'Kampong Bahru Road',
#   u'Craig Road, 7, Singapore, Craig, Tanjong Pagar, Central'),
#  (u'Kampong Bahru Road',
#   u'Kampong Bahru Road, 37, Singapore, Bahru, Outram Road, Tiong Bahru, Central'),
#  (u'Kasai Road',
#   u'Seletar Hills Estate, Kasai Road, 3, Singapore, Kasai, Yio Chu Kang, Northeast'),
#  (u'Kasai Road',
#   u'Seletar Hills Estate, Kasai Road, 5, Singapore, Kasai, Yio Chu Kang, Northeast'),
#  (u'Kent Ridge Road',
#   u'Kent Ridge Road, 12A, Singapore, Kent Ridge, Pasir Panjang, Alexandra, Kent Ridge, West'),
#  (u'Keong Saik Road',
#   u'Keong Saik Road, 35, Singapore, Keong Saik, Tanjong Pagar, Central'),
#  (u'Keong Saik Road',
#   u'Keong Saik Road, 36, Singapore, Keong Saik, Tanjong Pagar, Central'),
#  (u'Keppel Bay Vista',
#   u'Marina At Keppel Bay, Keppel Bay Vista, 2, Singapore, Keppel, Habourfront, Telok Blangah, Central'),
#  (u'Keppel Road',
#   u'Tanjong Pagar Complex, Keppel Road, 7B, Singapore, Keppel, Tanjong Pagar, Central'),
#  (u'Kim Tian Road',
#   u'Kim Tian Road, 126A, Singapore, Kim Tian, Outram Road, Tiong Bahru, Central'),
#  (u"King George's Avenue",
#   u"King George's Building, King George's Avenue, 344, Singapore, King George's, Lavender, Jalan Besar, Central"),
#  (u'King George\u2019s Avenue',
#   u"King George's Building, King George's Avenue, 344, Singapore, King George's, Lavender, Jalan Besar, Central"),
#  (u'Kitchener Road',
#   u'Kitchener Road, 153, Singapore, Kitchener, Lavender, Jalan Besar, Central'),
#  (u'Kreta Ayer Road',
#   u'Kreta Ayer Road, 28, Singapore, Kreta Ayer, Tanjong Pagar, Central'),
#  (u'Lor Ah Soo',
#   u"Paya Lebar Methodist Girls' Secondary School, Lorong Ah Soo, 296, Singapore, Ah Soo, Hougang, Serangoon, Yio Chu Kang, Kovan, Northeast"),
#  (u'Lor Liput',
#   u'Holland Village, Lorong Liput, 15, Singapore, Liput, Holland Road, Ghim Moh, West'),
#  (u'Lor Telok', u'Lorong Telok, 11, Singapore, Telok, Raffles Place, Central'),
#  (u'Lorong 1A Toa Payoh',
#   u'Lorong 1a Toa Payoh, 138B, Singapore, Toa Payoh, Braddell, Toa Payoh, Northeast'),
#  (u'Lorong 1A Toa Payoh',
#   u'Lorong 1a Toa Payoh, 138C, Singapore, Toa Payoh, Braddell, Toa Payoh, Northeast'),
#  (u'Lorong 1A Toa Payoh',
#   u'Lorong 1a Toa Payoh, 139A, Singapore, Toa Payoh, Braddell, Toa Payoh, Northeast'),
#  (u'Lorong 1A Toa Payoh',
#   u'Lorong 1a Toa Payoh, 139B, Singapore, Toa Payoh, Braddell, Toa Payoh, Northeast'),
#  (u'Lorong 2 Toa Payoh',
#   u'Lorong 1a Toa Payoh, 138A, Singapore, Toa Payoh, Braddell, Toa Payoh, Northeast'),
#  (u'Lorong Liput',
#   u'Holland Village, Lorong Liput, 33, Singapore, Liput, Holland Road, Ghim Moh, West'),
#  (u'Lorong Tanggam',
#   u'Lorong Tanggam, 24A, Singapore, Tanggam, Seletar, Northeast'),
#  (u'Lorong Tanggam',
#   u'Lorong Tanggam, 33A, Singapore, Tanggam, Seletar, Northeast'),
#  (u'Lorong Tanggam',
#   u'Lorong Tanggam, 35A, Singapore, Tanggam, Seletar, Northeast'),
#  (u'Lorong Tanggam',
#   u'Lorong Tanggam, 37A, Singapore, Tanggam, Seletar, Northeast'),
#  (u'Lorong Tanggam',
#   u'Lorong Tanggam, 93A, Singapore, Tanggam, Seletar, Northeast'),
#  (u'Lorong Tanggam',
#   u'Lorong Tanggam, 93B, Singapore, Tanggam, Seletar, Northeast'),
#  (u'Lorong Tanggam',
#   u'Lorong Tanggam, 95A, Singapore, Tanggam, Seletar, Northeast'),
#  (u'Loyang Avenue',
#   u'Loyang Valley, Loyang Avenue, 214, Singapore, Loyang, Loyang, East'),
#  (u'Mandai Road',
#   u'Mandai Pub Office Water Department, Mandai Road, Singapore, Mandai, Sector 77, North'),
#  (u'Margaret Drive',
#   u'Queensway Secondary School, Margaret Drive, 2A, Singapore, Margaret, Queenstown, Commonwealth, Central'),
#  (u'Marina Boulevard',
#   u'Marina Boulevard, 10, Singapore, Marina, Marina South, Central'),
#  (u'Marina Boulevard',
#   u'Marina Boulevard, 8, Singapore, Marina, Marina South, Central'),
#  (u'Marina Boulevard',
#   u'The Sail @ Marina Bay, Marina Boulevard, 4, Singapore, Marina, Marina South, Central'),
#  (u'Marina Boulevard',
#   u'The Sail @ Marina Bay, Marina Boulevard, 6, Singapore, Marina, Marina South, Central'),
#  (u'Marina View', u'Marina View, 8, Singapore, Marina, Marina South, Central'),
#  (u'Marind Drive',
#   u'Marine Parade Central, 86, Singapore, Marine, Marine Parade, East'),
#  (u'Marine Drive',
#   u'Marine Drive, 77, Singapore, Marine, Marine Parade, East'),
#  (u'Marine Parade Road Park',
#   u'Marine Parade Community Centre, Marine Parade Road, 278, Singapore, Marine, Marine Parade, East'),
#  (u'Market Street',
#   u'Bank of East Asia Building, Market Street, 137, Singapore, Market, Raffles Place, Central'),
#  (u'Merchant Road',
#   u'Riverside Point, Merchant Road, 30, Singapore, Merchant, Chinatown, Central'),
#  (u'Merchant Road',
#   u'Stamford Road, 2, Singapore, Stamford, Central Fire Station, Hill Street, Central'),
#  (u'Mimosa Crescent',
#   u'Mimosa Crescent, 105A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Crescent',
#   u'Mimosa Crescent, 105B, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Crescent',
#   u'Seletar Hills Estate, Mimosa Crescent, 108A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Crescent',
#   u'Seletar Hills Estate, Mimosa Crescent, 117A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 18A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 20A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 22A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 24A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 26A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 28A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 30A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 32A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Mimosa Road, 38A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Seletar Hills Estate, Mimosa Road, 10A, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Seletar Hills Estate, Mimosa Road, 10B, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Mimosa Road',
#   u'Seletar Hills Estate, Mimosa Road, 10C, Singapore, Mimosa, Yio Chu Kang, Northeast'),
#  (u'Minden Road',
#   u'Minden Road, 130E, Singapore, Minden, Tanglin Road, River Valley, Central'),
#  (u'Mosque Street',
#   u'Mosque Street, 14, Singapore, Mosque, Chinatown, Central'),
#  (u'Mosque Street',
#   u'Mosque Street, 27, Singapore, Mosque, Chinatown, Central'),
#  (u'Mount Elizabeth',
#   u'Elizabeth Tower, Mount Elizabeth, 14, Singapore, Mount Elizabeth, Cavenagh Road, Scotts Road, Newton, Central'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11A, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11B, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11C, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11D, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11E, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11F, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11G, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Lane',
#   u'Glentrees, Mount Sinai Lane, 11H, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Mount Sinai Rise',
#   u'The Marbella, Mount Sinai Rise, 29, Singapore, Mount Sinai, Holland Road, Ghim Moh, West'),
#  (u'Murai Farmway',
#   u'Murai Farmway, 1A, Singapore, Murai, Lim Chu Kang, West'),
#  (u'Murai Farmway',
#   u'Murai Lodge One, Murai Farmway, 1B, Singapore, Murai, Lim Chu Kang, West'),
#  (u'Neram Road',
#   u'Seletar Hills Estate, Neram Road, 18A, Singapore, Neram, Yio Chu Kang, Northeast'),
#  (u'Neram Road',
#   u'Seletar Hills Estate, Neram Road, 1A, Singapore, Neram, Yio Chu Kang, Northeast'),
#  (u'Nim Crescent',
#   u'Nim Crescent, 5A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Crescent',
#   u'Seletar Hills Estate, Nim Crescent, 1A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Crescent',
#   u'Seletar Hills Estate, Nim Crescent, 1B, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Drive',
#   u'Seletar Hills Estate, Nim Drive, 18A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 12A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 14A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 16A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 18A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 1A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 1B, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 26A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green', u'Nim Green, 28A, Singapore, Nim, Yio Chu Kang, Northeast'),
#  (u'Nim Green',
#   u'Stratton Drive, 42, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Nim Green',
#   u'Stratton Drive, 43, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Nim Green',
#   u'Stratton Drive, 44, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Nim Green',
#   u'Stratton Drive, 45, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Nim Green',
#   u'Stratton Drive, 46, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'North Boat Quay',
#   u'High Street Centre, North Bridge Road, 1, Singapore, North Bridge, Central Fire Station, Hill Street, Central'),
#  (u'North Buona Vista Road',
#   u'Buona Vista Mrt Station, North Buona Vista Road, 100, Singapore, North Buona Vista, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'North Canal Road',
#   u'North Canal Road, 12, Singapore, North Canal, Raffles Place, Central'),
#  (u'Orchard Road',
#   u'Ion Orchard, Orchard Turn, 2, Singapore, Orchard, Orchard Road, Central'),
#  (u'Orchard Road',
#   u'Ngee Ann City Tower B, Orchard Road, 391B, Singapore, Orchard, Orchard Road, Central'),
#  (u'Orchard Road',
#   u'Orchard Hotel, Orchard Road, 442, Singapore, Orchard, Orchard Road, Central'),
#  (u'Orchard Road',
#   u'Orchard Road, 33A, Singapore, Orchard, Orchard Road, Central'),
#  (u'Pagoda Street',
#   u'Mosque Street, 44, Singapore, Mosque, Chinatown, Central'),
#  (u'Pasir Panjang Road',
#   u'Pasir Panjang Road, 245A, Singapore, Pasir Panjang, Pasir Panjang, Alexandra, Kent Ridge, West'),
#  (u'Pasir Ris Street 52',
#   u'Edgefield Primary School, Edgefield Plains, 41, Singapore, Edgefield, Punggol, Northeast'),
#  (u'Paterson Road',
#   u'Overseas Family School, Paterson Road, 25F, Singapore, Paterson, Orchard Road, Central'),
#  (u'Pekin Street',
#   u'Pekin Street, 45, Singapore, Pekin, Raffles Place, Central'),
#  (u'Pickering Street',
#   u'Pickering Operation Centre, Pickering Street, 20, Singapore, Pickering, Raffles Place, Central'),
#  (u'Pine Grove',
#   u'Cavendish Park, Pine Grove, 18, Singapore, Pine, Bukit Timah, King Albert Park, North'),
#  (u'Pine Grove',
#   u'Pine Grove, 3, Singapore, Pine, Bukit Timah, King Albert Park, North'),
#  (u'Punggol Place',
#   u'Punggol Place, 70A, Singapore, Punggol, Punggol, Northeast'),
#  (u'Queensway',
#   u'Mobil Service Station, Queensway, 262, Singapore, Queensway, Queenstown, Commonwealth, Central'),
#  (u'Raffles Place',
#   u'Singapore Flyer, Raffles Avenue, 30, Singapore, Raffles, Marina, Esplanade, Suntec, Central'),
#  (u'Raffles Quay',
#   u'Asia Insurance Building, Finlayson Green, 2, Singapore, Finlayson, Raffles Place, Central'),
#  (u'Raffles Quay',
#   u'Hong Leong Building, Raffles Quay, 16, Singapore, Raffles, Raffles Place, Central'),
#  (u'Rangoon Road #01-02',
#   u'Rangoon Road, 88, Singapore, Rangoon, Little India, Central'),
#  (u'Redhill Lane',
#   u'Redhill Close, 87, Singapore, Redhill, Redhill, Bukit Merah, Alexandra, Central'),
#  (u'Redhill Lane',
#   u'Redhill Close, 88, Singapore, Redhill, Redhill, Bukit Merah, Alexandra, Central'),
#  (u'Ridgwood Close',
#   u'Ridgewood Condominium, Ridgewood Close, 5, Singapore, Ridgewood, Holland Road, Ghim Moh, West'),
#  (u'Ridley Park',
#   u'Tanglin Park, Ridley Park, 1B, Singapore, Ridley, Tanglin Road, River Valley, Central'),
#  (u'River Valley Road',
#   u'Hotel New Otani, River Valley Road, 177A, Singapore, River Valley, Central Fire Station, Hill Street, Central'),
#  (u'River Valley Road',
#   u'Liang Court Shopping Centre, River Valley Road, 177, Singapore, River Valley, Central Fire Station, Hill Street, Central'),
#  (u'River Valley Road',
#   u'Liang Court, River Valley Road, 177B, Singapore, River Valley, Central Fire Station, Hill Street, Central'),
#  (u'River Valley Road',
#   u"Traders' Market, River Valley Road, 3E, Singapore, River Valley, Central Fire Station, Hill Street, Central"),
#  (u'Robinson Road',
#   u'Capital Tower, Robinson Road, 168, Singapore, Robinson, Robinson Road, Shenton Way, Central'),
#  (u'Robinson Road',
#   u'Cpf Building, Robinson Road, 79, Singapore, Robinson, Robinson Road, Shenton Way, Central'),
#  (u'Robinson Road',
#   u'Far East Finance Building, Robinson Road, 14, Singapore, Robinson, Raffles Place, Central'),
#  (u'Robinson Road',
#   u'Parakou Building, Robinson Road, 120, Singapore, Robinson, Robinson Road, Shenton Way, Central'),
#  (u'Rochester Drive',
#   u'The Rochester, Rochester Drive, 31, Singapore, Rochester, Dover, Buona Vista, Singapore Polytechnic, West'),
#  (u'Rochor Canal Road',
#   u'Sim Lim Square, Rochor Canal Road, 1, Singapore, Rochor, Bugis, Victoria Street, Rochor, Central'),
#  (u'Rochor Canal Road #02-85',
#   u'Sim Lim Square, Rochor Canal Road, 1, Singapore, Rochor, Bugis, Victoria Street, Rochor, Central'),
#  (u'Rowell Road',
#   u'Rowell Road, 641, Singapore, Rowell, Lavender, Jalan Besar, Central'),
#  (u'Sandy Lane',
#   u'Our Lady Queen of Peace Church, Sandy Lane, 4, Singapore, Sandy, Katong, Tanjong Rhu, East'),
#  (u'Saraca Drive',
#   u'Saraca Road, 101, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 103, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 105, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 107, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 109, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 91, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 93, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 95, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 97, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Drive',
#   u'Saraca Road, 99, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Hill',
#   u'Saraca Hill, 4A, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Hill',
#   u'Saraca Hill, 4B, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Hill',
#   u'Saraca Hill, 4C, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Road',
#   u'Saraca Road, 119, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Road',
#   u'Saraca Road, 121, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Road',
#   u'Saraca Road, 123, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Road',
#   u'Saraca Road, 125, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Road',
#   u'Saraca Road, 127, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Road',
#   u'Saraca Road, 129, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Terrace',
#   u'Seletar Hills Estate, Saraca Road, 45, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Terrace',
#   u'Seletar Hills Estate, Saraca Road, 59, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Saraca Walk',
#   u'Saraca Walk, 2, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 48, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 50, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 52, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 54, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 56, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 58, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 60, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Sarca View',
#   u'Saraca View, 62, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Science Drive 3',
#   u'Science Drive 2, 2, Singapore, Science, Pasir Panjang, Alexandra, Kent Ridge, West'),
#  (u'Seah Street',
#   u'Middle Road, 31, Singapore, Middle, Bugis, Victoria Street, Rochor, Central'),
#  (u'Seah Street',
#   u'New Bridge Road, 181, Singapore, New Bridge, Chinatown, Central'),
#  (u'Seah Street',
#   u'Og Building, Upper Cross Street, 100, Singapore, Upper Cross, Chinatown, Central'),
#  (u'Seletar West Farmway 6',
#   u'Seletar West Farmway 6, 2, Singapore, Seletar, Seletar, Northeast'),
#  (u'Seng Kang East Way',
#   u'Chij St. Joseph Convent School, Sengkang East Way, 62, Singapore, Sengkang, Sengkang, Buangkok, Northeast'),
#  (u'Seragoon North Avenue 2',
#   u'Masjid Al-istiqamah, Serangoon North Avenue 2, 2, Singapore, Serangoon, Serangoon Central, Serangoon Gardens, Northeast'),
#  (u'Serangoon Garden Way',
#   u'Serangoon Garden Estate, Serangoon Garden Way, 66, Singapore, Serangoon, Serangoon Central, Serangoon Gardens, Northeast'),
#  (u'Shenton Way',
#   u'One Shenton, Shenton Way, 1, Singapore, Shenton, Robinson Road, Shenton Way, Central'),
#  (u'Shenton Way',
#   u'Sgx Centre I, Shenton Way, 2, Singapore, Shenton, Robinson Road, Shenton Way, Central'),
#  (u'Shenton Way',
#   u'Sgx Centre II, Shenton Way, 4, Singapore, Shenton, Robinson Road, Shenton Way, Central'),
#  (u'Silat Avenue',
#   u'Silat Avenue, 149, Singapore, Silat, Outram Road, Tiong Bahru, Central'),
#  (u'Sims Drive #05-12B',
#   u'Shun Li Industrial Complex, Sims Drive, 705, Singapore, Sims, Kallang, Aljunied, Geylang, East'),
#  (u'Smith Street', u'Smith Street, 13, Singapore, Smith, Chinatown, Central'),
#  (u'Smith Street', u'Smith Street, 31, Singapore, Smith, Chinatown, Central'),
#  (u'Smith Street',
#   u'Smith Street, 335A, Singapore, Smith, Chinatown, Central'),
#  (u'Smith Street',
#   u'Smith Street, 335B, Singapore, Smith, Chinatown, Central'),
#  (u'Smith Street', u'Smith Street, 37, Singapore, Smith, Chinatown, Central'),
#  (u'Smith Street', u'Smith Street, 52, Singapore, Smith, Chinatown, Central'),
#  (u'South Bridge Road',
#   u'South Bridge Road, 268, Singapore, South Bridge, Chinatown, Central'),
#  (u"St Patrick's Road",
#   u"St. Patrick's Green, St. Patrick's Road, 49, Singapore, St. Patrick's, Katong, Joo Chiat, East"),
#  (u'St Wilfred Road',
#   u'Bendemeer Secondary School, St. Wilfred Road, 1, Singapore, St. Wilfred, Balestier, Bendemeer, Northeast'),
#  (u'Strathmore Avenue',
#   u'Strathmore Avenue, 62B, Singapore, Strathmore, Queenstown, Commonwealth, Central'),
#  (u'Stratton Green',
#   u'Saraca Road, 109, Singapore, Saraca, Yio Chu Kang, Northeast'),
#  (u'Stratton Green',
#   u'Stratton Green, 2A, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Stratton Green',
#   u'Stratton Green, 2B, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Stratton Green',
#   u'Stratton Green, 2D, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Stratton Green',
#   u'Stratton Green, 2E, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Stratton Green',
#   u'Stratton Green, 2F, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Stratton Green',
#   u'Stratton Green, 2G, Singapore, Stratton, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serene Park, Tamarind Road, 37, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serene Park, Tamarind Road, 41, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serene Park, Tamarind Road, 45, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serenity Park, Tamarind Road, 157A, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serenity Park, Tamarind Road, 157B, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serenity Park, Tamarind Road, 157C, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serenity Park, Tamarind Road, 157E, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serenity Park, Tamarind Road, 157F, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Serenity Park, Tamarind Road, 157G, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 101, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 103, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 105, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 107, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 109, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 4B, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 4C, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tamarind Road',
#   u'Tamarind Road, 4D, Singapore, Tamarind, Yio Chu Kang, Northeast'),
#  (u'Tampines Avenue 1',
#   u'The Tropica, Tampines Avenue 1, 51, Singapore, Tampines, Tampines, Simei, East'),
#  (u'Tampines Grande',
#   u'Aia Tower, Robinson Road, 1, Singapore, Robinson, Raffles Place, Central'),
#  (u'Tampines Street 42',
#   u'Gan Eng Seng Primary School, Redhill Close, 100, Singapore, Redhill, Redhill, Bukit Merah, Alexandra, Central'),
#  (u'Tampines Street 83',
#   u'Tampines Central Community Complex, Tampines Street 83, 866A, Singapore, Tampines, Tampines, Simei, East'),
#  (u'Tanjong Pagar Road',
#   u'Tanjong Pagar Road, 37, Singapore, Tanjong Pagar, Tanjong Pagar, Central'),
#  (u'Teck Lim Road',
#   u'Keong Saik Road, 31, Singapore, Keong Saik, Tanjong Pagar, Central'),
#  (u'Teck Lim Road',
#   u'Teck Lim Road, 12, Singapore, Teck Lim, Tanjong Pagar, Central'),
#  (u'Telok Ayer Street',
#   u'Telok Ayer Street, 169, Singapore, Telok Ayer, Robinson Road, Shenton Way, Central'),
#  (u'Telok Ayer Street',
#   u'Telok Ayer Street, 181, Singapore, Telok Ayer, Robinson Road, Shenton Way, Central'),
#  (u'Telok Blangah Cresent',
#   u'Radin Mas Community Centre, Telok Blangah Crescent, 1, Singapore, Telok Blangah, Habourfront, Telok Blangah, Central'),
#  (u'Temasek Boulevard',
#   u'Suntec City Mall, Temasek Boulevard, 3, Singapore, Temasek, Marina, Esplanade, Suntec, Central'),
#  (u'Temasek Boulevard',
#   u'Suntec Tower Four, Temasek Boulevard, 6, Singapore, Temasek, Marina, Esplanade, Suntec, Central'),
#  (u'Temasek Boulevard',
#   u'Suntec Tower One, Temasek Boulevard, 7, Singapore, Temasek, Marina, Esplanade, Suntec, Central'),
#  (u'Temasek Boulevard',
#   u'Suntec Tower Three, Temasek Boulevard, 8, Singapore, Temasek, Marina, Esplanade, Suntec, Central'),
#  (u'Temple Street',
#   u'Temple Street, 65, Singapore, Temple, Chinatown, Central'),
#  (u'Toh Guan Road East',
#   u'Toh Guan Dormitory, Toh Guan Road East, 19A, Singapore, Toh Guan, Jurong East, West'),
#  (u'Toh Guan Road East',
#   u'Toh Guan Road East, 5A, Singapore, Toh Guan, Jurong East, West'),
#  (u'Tuas View Avenue 14',
#   u'Tuas South Avenue 14, 20, Singapore, Tuas, Jurong, Tuas, West'),
#  (u'Unit : #05-464,  Hougang Street 51',
#   u'Hougang Street 51, 566, Singapore, Hougang, Hougang, Serangoon, Yio Chu Kang, Kovan, Northeast'),
#  (u'Upper Pickering Street',
#   u'Smith Street, 31, Singapore, Smith, Chinatown, Central'),
#  (u'Upper Thomson Road',
#   u'Thomson Garden Estate, Upper Thomson Road, 220, Singapore, Upper Thomson, Bishan, Thomson Road, Northeast'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 59, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 61, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 63, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 65, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 67, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 69, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 71, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 73, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 75, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'Verde View',
#   u'Villa Verde, Verde View, 77, Singapore, Verde, Yew Tee, Choa Chu Kang, North'),
#  (u'West Coast Road',
#   u'West Coast Plaza, West Coast Road, 154, Singapore, West Coast, Clementi, West'),
#  (u'Whampoa Drive',
#   u'Ah Hood Road, 101, Singapore, Ah Hood, Balestier, Bendemeer, Northeast'),
#  (u'Whampoa Drive',
#   u'Jalan Dusun, 104, Singapore, Dusun, Balestier, Bendemeer, Northeast'),
#  (u'Woodlands Street 13',
#   u'Marsiling Apartments, Woodlands Street 13, 52, Singapore, Woodlands, Woodlands, Marsiling, Amiralty, North'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 345A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 345B, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 345C, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 347A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 347B, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 347C, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 349A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 349B, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 349C, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 351A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 351B, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 351C, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 353A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 355A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 355B, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 355C, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yio Chu Kang Road',
#   u'Tuan Sing Park, Yio Chu Kang Road, 357A, Singapore, Yio Chu Kang, Yio Chu Kang, Northeast'),
#  (u'Yishun Avenue 6',
#   u'Ahmad Ibrahim Secondary School, Yishun Avenue 7, 751, Singapore, Yishun, Yishun, Khatib, North'),
#  (u'Yishun Avenue 6',
#   u'North Spring Primary School, Rivervale Street, 1, Singapore, Rivervale, Sengkang, Buangkok, Northeast'),
#  (u'Yishun Avenue 6',
#   u'Yishun Avenue 6, 405, Singapore, Yishun, Yishun, Khatib, North'),
#  (u'Yishun Avenue 6',
#   u'Yishun Avenue 6, 406, Singapore, Yishun, Yishun, Khatib, North'),
#  (u'Yishun Avenue 7',
#   u'Yishun Avenue 7, 2B, Singapore, Yishun, Yishun, Khatib, North'),
#  (u'Yishun Street 71',
#   u'Innova Primary School, Woodlands Drive 17, 80, Singapore, Woodlands, Woodlands, Marsiling, Amiralty, North'),
#  (u'Yishun Street 81',
#   u'Yishun Street 81, 867, Singapore, Yishun, Yishun, Khatib, North'),
#  (u'Yuan Ching Road',
#   u'Yuan Ching Road, 134D, Singapore, Yuan Ching, Taman Jurong, West')}

# %%
db.mapdata_new.find_one({'type': 'both info avail, found but no match', 'address.address.street': 'Bukit Batok East Avenue 5'})
# Out:
# {u'_id': ObjectId('56e5e77905482103361bbbf9'),
#  u'add_post': {u'_id': ObjectId('56e2482394e1beeae67238a2'),
#   u'building': None,
#   u'city': u'Singapore',
#   u'full': u'Bukit Batok East Avenue 5, 233, Singapore, Bukit Batok, Bukit Batok, Bukit Gombak, West',
#   u'postcode': u'650233',
#   u'region1': u'West',
#   u'region2': u'Bukit Batok, Bukit Gombak',
#   u'region3': u'Singapore',
#   u'street': u'Bukit Batok East Avenue 5, 233'},
#  u'add_st': u'bukit batok east avenue 5',
#  u'address': {u'_id': ObjectId('56e3174794e1bedc4b685290'),
#   u'address': {u'city': u'Singapore',
#    u'housename': u'Blk 233',
#    u'housenumber': u'#01-43',
#    u'postcode': u'650233',
#    u'street': u'Bukit Batok East Avenue 5'},
#   u'created': {u'changeset': u'24455268',
#    u'timestamp': u'2014-07-31T03:33:02Z',
#    u'uid': u'602634',
#    u'user': u'matx17',
#    u'version': u'3'},
#   u'id': u'2988807958',
#   u'name': {u'default': u'HYBRID SCUBA'},
#   u'opening_hours': {u'default': u'Mon - Thurs: 1pm to 9pm  Fri, Sat  & Sun  (By Appointment Only)'},
#   u'phone': {u'default': u'(65) 9387 4347 / (65) 9026 5781'},
#   u'pos': [1.3487668, 103.7552076],
#   u'shop': {u'default': u'yes'},
#   u'type': u'node',
#   u'website': {u'default': u'www.hybridscuba.com'}},
#  u'type': u'both info avail, found but no match'}

# %% [markdown]
# ### Sample Output

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = filename  # Replace this with your osm file
SAMPLE_FILE = "datasets/sample.osm"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every 10th top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % 10 == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# ### source
# - http://stackoverflow.com/questions/7684815/regex-for-alphanumeric-with-at-least-1-number-and-1-character
# - http://stackoverflow.com/questions/19923536/getting-a-list-of-unique-embedded-nested-objects-in-a-mongodb-document
# - http://stackoverflow.com/questions/6930982/how-to-use-a-variable-inside-a-regular-expression
# - http://stackoverflow.com/questions/2436607/how-to-use-re-match-objects-in-a-list-comprehension
